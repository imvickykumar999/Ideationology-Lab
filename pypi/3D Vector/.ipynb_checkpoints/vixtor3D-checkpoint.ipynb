# %% [markdown]
# # >>> Tutorial link :
#
# ### https://github.com/imvickykumar999/vixtor/blob/master/pip%20install%20vixtor%20version%200.0.2.ipynb

# %% [markdown]
# ## >>> pip install vixtor
#
# [![pip](https://camo.githubusercontent.)](https://pypi.org/project/vixtor/)

# %%
# !pip install --upgrade vixtor
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for vixtor, since package 'wheel' is not installed.
# ...
#   Running setup.py install for vixtor: started
#   Running setup.py install for vixtor: finished with status 'done'
# ...

# %%
import vixtor
# Out:
# >>> Available functions in vixtor Package are...
#
#
# 	...try this,
#
# 	from vixtor import threeDvector as vix
# 	print( vix.angbw2line( printing = True ))
#
# >>> Made with LOVE and HARDWORK...
#
# 	mod(vector=[2,1,2])
#
# 	showline(a=[-1, 0, 2], b=[4, 4, 4], u=10)
#
# 	showplane(n=[1, 1, 2])
#
# 	line(a=[1, 2, -4], b=[2, 3, 6],
# 	two_points=False, sno='', printing=False)
#
# 	plane(a=[2, 5, -3], n=[-2, -3, 5], p=[5, 3, -3], dis=34,
# 	nd=False, three_points=False, sno='', printing=False)
#
# 	comp_hcf(x=15, y=80)
#
# 	angbw2line(a1=[3, 2, -4], b1=[1, 2, 2],
# 	a2=[5, -2, 0], b2=[3, 2, 6], printing=False)
#
# 	distbw2line(a1=[1, 2, -4], b1=[2, 3, 6],
# 	a2=[3, 3, -5], b2=[2, 3, 6], printing=False)
#
# 	coplanof2line(a1=[-3, 1, 5], b1=[-3, 1, 5],
# 	a2=[-1, 2, 5], b2=[-1, 2, 5], printing=False)
#
# 	angbw2plane(n1=[3, -6, 2], d1=7,
# 	n2=[2, 1, -2], d2=5, printing=False)
#
# 	distbwpointandplane(a=[2, 5, -3],
# 	n=[6, -3, 2], d=4, printing=False)
#
# ...

# %%
# !pip install matplotlib

from vixtor import threeDvector as vix

vix
# Out:
# ...
#   Using cached matplotlib-3.5.2-cp310-cp310-win_amd64.whl (7.2 MB)
# ...
#      ---------------------------------------- 55.3/55.3 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
# ...
#      -------------------------------------- 944.1/944.1 kB 4.6 MB/s eta 0:00:00
# ...
# <module 'vixtor.threeDvector' from 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\vixtor\\threeDvector.py'>

# %%
angle = vix.angbw2plane(printing = True)
angle
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (3) i+ (-6) j+ (2)k ] = 0
#
#             r.[ (3) i+ (-6) j+ (2)k ] = 7
#
#         Cartesian form :
#             (3)(x- (2)) + (-6)(y- (5)) + (2)(z- (-3)) = 0
#
#             (3)x + (-6)y + (2)z = 7
#
#         Intercept form :
#                x/(2.333) + y/(-1.167) + z/(3.500) = 1
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (1) j+ (-2)k ] = 0
#
#             r.[ (2) i+ (1) j+ (-2)k ] = 5
#
#         Cartesian form :
#             (2)(x- (2)) + (1)(y- (5)) + (-2)(z- (-3)) = 0
#
#             (2)x + (1)y + (-2)z = 5
#
#         Intercept form :
#                x/(2.500) + y/(5.000) + z/(-2.500) = 1
#
# >>> Planes are [ NOT ] Parallel...
#
#         Angle between Planes...
#
#         r.((3)i+(-6)j+(2)k) = 7 and
#         r.((2)i+(1)j+(-2)k) = 5 is...
#
#
#         angle = arccos( abs( -4/21.0 ))
# ...

# %%
vix.angbw2line(printing = True)
# Out:
#     >>> Line1...
#
#         Vector Form :
#             r = [ (3)i + (2)j + (-4)k ] + u*[ (1)i + (2)j + (2)k ]
#
#         Cartesian form :
#
#             [x- (3)] / (2) = [y- (-4)] / (1) = [z- (2)] / (2)
#     >>> Line2...
#
#         Vector Form :
#             r = [ (5)i + (-2)j + (0)k ] + u*[ (3)i + (2)j + (6)k ]
#
#         Cartesian form :
#
#             [x- (5)] / (-2) = [y- (0)] / (3) = [z- (2)] / (6)
#     >>> Angle between :
#
#         Line1...
#         r = (3)i+(2)j+(-4)k + u((1)i+(2)j+(2)k)
#
#         and, Line2...
#         r = (5)i+(-2)j+(0)k + u((3)i+(2)j+(6)k) is...
#
#
#         angle = arccos( abs( 19/21.0 ))
#         = arccos( sqrt( 361 ) / sqrt( 441.0 ))
#         = arccos( 0.9047619047619048 )
#         = 0.4399759547909189 radian
#         = 25.20886230570049 degree
# 25.20886230570049

# %%
vix.angbw2line()
# Out:
# 25.20886230570049

# %%
l = vix.line(a=[5,2,-4], b=[3,2,-8], printing = True)
l
# Out:
#     >>> Line...
#
#         Vector Form :
#             r = [ (5)i + (2)j + (-4)k ] + u*[ (3)i + (2)j + (-8)k ]
#
#         Cartesian form :
#
#             [x- (5)] / (2) = [y- (-4)] / (3) = [z- (2)] / (-8)
# (array([ 5,  2, -4]), array([ 3,  2, -8]))

# %%
vix.distbw2line(a1=[1,1,0], b1=[2,-1,1], a2=[2,1,-1], b2=[3,-5,2], printing = True)
# Out:
#     >>> Line1...
#
#         Vector Form :
#             r = [ (1)i + (1)j + (0)k ] + u*[ (2)i + (-1)j + (1)k ]
#
#         Cartesian form :
#
#             [x- (1)] / (1) = [y- (0)] / (2) = [z- (-1)] / (1)
#     >>> Line2...
#
#         Vector Form :
#             r = [ (2)i + (1)j + (-1)k ] + u*[ (3)i + (-5)j + (2)k ]
#
#         Cartesian form :
#
#             [x- (2)] / (1) = [y- (-1)] / (3) = [z- (-5)] / (2)
#
# >>> Lines are [ NOT ] Parallel...
#
#         Distance between Lines...
#
#         r = (1)i+(1)j+(0)k + l((2)i+(-1)j+(1)k) and
#         r = (2)i+(1)j+(-1)k + u((3)i+(-5)j+(2)k) is...
#
#
#         distance = sqrt( 100 ) / sqrt( 58.99999999999999 )
#         = 10/7.681145747868608
#         = 1.3018891098082388 units.
# 1.3018891098082388

# %%
vix.distbwpointandplane(a=[0,0,0], n=[2,-3,4], d=6, printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (2) i+ (-3) j+ (4)k ] = 0
#
#             r.[ (2) i+ (-3) j+ (4)k ] = 6
#
#         Cartesian form :
#             (2)(x- (2)) + (-3)(y- (5)) + (4)(z- (-3)) = 0
#
#             (2)x + (-3)y + (4)z = 6
#
#         Intercept form :
#                x/(3.000) + y/(-2.000) + z/(1.500) = 1
#     >>> Distance between :
#
#         Plane...
#         r.((2)i+(-3)j+(4)k) = 6
#
#         and, Point (0,0,0) is...
#         = sqrt( 36 ) / sqrt( 28.999999999999996 )
#         = 6 / 5.385164807134504
#         = 1.1141720290623112 units.
# 1.1141720290623112

# %%
vix.plane(a=[5,2,-4], n=[2,3,-1], printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (5)i + (2)j + (-4)k ) ].[ (2) i+ (3) j+ (-1)k ] = 0
#
#             r.[ (2) i+ (3) j+ (-1)k ] = 20
#
#         Cartesian form :
#             (2)(x- (5)) + (3)(y- (2)) + (-1)(z- (-4)) = 0
#
#             (2)x + (3)y + (-1)z = 20
#
#         Intercept form :
#                x/(10.000) + y/(6.667) + z/(-20.000) = 1
# (array([ 5,  2, -4]), array([ 2,  3, -1]), 20)

# %%
vix.plane(a=[2,5,-3], n=[-2,-3,5], p=[5,3,-3], three_points = True, printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (5)j + (-3)k ) ].[ (16) i+ (24) j+ (32)k ] = 0
#
#             r.[ (16) i+ (24) j+ (32)k ] = 56
#
#         Cartesian form :
#             (16)(x- (2)) + (24)(y- (5)) + (32)(z- (-3)) = 0
#
#             (16)x + (24)y + (32)z = 56
#
#         Intercept form :
#                x/(3.500) + y/(2.333) + z/(1.750) = 1
# (array([ 2,  5, -3]), array([16, 24, 32]), 56)

# %%
vix.plane(a=[2,-5,3], n=[3,6,5], three_points = 0, printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (2)i + (-5)j + (3)k ) ].[ (3) i+ (6) j+ (5)k ] = 0
#
#             r.[ (3) i+ (6) j+ (5)k ] = -9
#
#         Cartesian form :
#             (3)(x- (2)) + (6)(y- (-5)) + (5)(z- (3)) = 0
#
#             (3)x + (6)y + (5)z = -9
#
#         Intercept form :
#                x/(-3.000) + y/(-1.500) + z/(-1.800) = 1
# (array([ 2, -5,  3]), array([3, 6, 5]), -9)

# %%
vix.plane(a=[3,7,-2], n=[2,-7,5], printing = True)
# Out:
#     >>> Plane...
#
#         Vector Form :
#             [ r - ( (3)i + (7)j + (-2)k ) ].[ (2) i+ (-7) j+ (5)k ] = 0
#
#             r.[ (2) i+ (-7) j+ (5)k ] = -53
#
#         Cartesian form :
#             (2)(x- (3)) + (-7)(y- (7)) + (5)(z- (-2)) = 0
#
#             (2)x + (-7)y + (5)z = -53
#
#         Intercept form :
#                x/(-26.500) + y/(7.571) + z/(-10.600) = 1
# (array([ 3,  7, -2]), array([ 2, -7,  5]), -53)

# %%
vix.angbwlineandplane(a=[-1,0,3], b=[2,3,6], n=[10,2,-11], d=3)
# Out:
# 22.392773977450503

# %%
vix.plane
# Out:
# <function vixtor.threeDvector.plane(a=[2, 5, -3], n=[-2, -3, 5], p=[5, 3, -3], dis=34, nd=False, three_points=False, sno='', printing=False)>
