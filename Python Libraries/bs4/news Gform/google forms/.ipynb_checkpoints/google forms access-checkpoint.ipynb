# %%
# >>> WARNING : for publicly open sheets
import pandas as pd

sheet_id = '18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv' 

df = pd.read_csv(url)
df
# Out:
#             Timestamp                        Email Address  \
# 0   9/1/2021 17:14:37                  puria8387@gmail.com
# 1   9/1/2021 17:15:02            imvickykumar999@gmail.com
# 2   9/1/2021 17:16:02             ayushsaini2911@gmail.com
# 3   9/1/2021 17:18:56                somya342000@gmail.com
# 4   9/1/2021 17:19:09             girishsonu2000@gmail.com
# 5   9/1/2021 17:25:28             ahmadnafees019@gmail.com
# 6   9/1/2021 17:47:02        madhurchauhan001256@gmail.com
# 7   9/1/2021 18:06:46   18erecs083.vikash@rietjaipur.ac.in
# 8   9/1/2021 18:47:47    18erecs084.vinay@rietjaipur.ac.in
# 9   9/1/2021 20:41:06    18erecs081.vijay@rietjaipur.ac.in
# 10  9/1/2021 22:55:24                   raorj123@gmail.com
# 11   9/2/2021 6:58:01          shubhampareek9571@gmail.com
# 12  9/2/2021 11:24:15                 pjadhavnsd@gmail.com
# 13   9/3/2021 9:45:58  18erecs040.namrata@rietjaipur.ac.in
# 14  9/3/2021 14:55:31  18erecs067.saransh@rietjaipur.ac.in
# ...

# %%
file_name = 'Internship Details.csv'
df.to_csv(file_name)

import os
os.startfile(file_name)

# %%
# !pip3 install gspread
# !pip3 install --upgrade google-api-python-client oauth2client
# Out:
# ...
# Requirement already up-to-date: google-api-python-client in c:\users\vicky\anaconda3\lib\site-packages (2.36.0)
# Requirement already up-to-date: oauth2client in c:\users\vicky\anaconda3\lib\site-packages (4.1.3)
# ...

# %%
jfile = 'ideationology-lab-b60654e44e37.json'
gc = pygsheets.authorize(service_file=jfile)
gc

# %%
help(gc)
# Out:
# Help on Client in module pygsheets.client object:
#
# class Client(builtins.object)
#  |  Client(credentials, retries=3, http=None, check=True, seconds_per_quota=100)
#  |
#  |  Create or access Google spreadsheets.
#  |
#  |  Exposes members to create new spreadsheets or open existing ones. Use `authorize` to instantiate an instance of this
#  |  class.
#  |
#  |  >>> import pygsheets
#  |  >>> c = pygsheets.authorize()
#  |
#  |  The sheet API service object is stored in the sheet property and the drive API service object in the drive property.
#  |
#  |  >>> c.sheet.get('<SPREADSHEET ID>')
#  |  >>> c.drive.delete('<FILE ID>')
#  |
#  |  :param credentials:             The credentials object returned by google-auth or google-auth-oauthlib.
#  |  :param retries:                 (Optional) Number of times to retry a connection before raising a TimeOut error.
#  |                                  Default: 3
# ...

# %%
spreadsheet_key = '18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM'
gt = gc.sheet.get(spreadsheet_key)
gt
# Out:
# {'spreadsheetId': '18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM',
#  'properties': {'title': 'Internship Details (Responses)',
#   'locale': 'en_US',
#   'autoRecalc': 'ON_CHANGE',
#   'timeZone': 'Asia/Calcutta',
#   'defaultFormat': {'backgroundColor': {'red': 1, 'green': 1, 'blue': 1},
#    'padding': {'top': 2, 'right': 3, 'bottom': 2, 'left': 3},
#    'verticalAlignment': 'BOTTOM',
#    'wrapStrategy': 'OVERFLOW_CELL',
#    'textFormat': {'foregroundColor': {},
#     'fontFamily': 'arial,sans,sans-serif',
#     'fontSize': 10,
#     'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'foregroundColorStyle': {'rgbColor': {}}},
#    'backgroundColorStyle': {'rgbColor': {'red': 1, 'green': 1, 'blue': 1}}},
#   'spreadsheetTheme': {'primaryFontFamily': 'Arial',
#    'themeColors': [{'colorType': 'TEXT', 'color': {'rgbColor': {}}},
#     {'colorType': 'BACKGROUND',
#      'color': {'rgbColor': {'red': 1, 'green': 1, 'blue': 1}}},
# ...

# %%
oaj = gc.open_as_json(spreadsheet_key)
oaj
# Out:
# {'spreadsheetId': '18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM',
#  'properties': {'title': 'Internship Details (Responses)',
#   'locale': 'en_US',
#   'autoRecalc': 'ON_CHANGE',
#   'timeZone': 'Asia/Calcutta',
#   'defaultFormat': {'backgroundColor': {'red': 1, 'green': 1, 'blue': 1},
#    'padding': {'top': 2, 'right': 3, 'bottom': 2, 'left': 3},
#    'verticalAlignment': 'BOTTOM',
#    'wrapStrategy': 'OVERFLOW_CELL',
#    'textFormat': {'foregroundColor': {},
#     'fontFamily': 'arial,sans,sans-serif',
#     'fontSize': 10,
#     'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'foregroundColorStyle': {'rgbColor': {}}},
#    'backgroundColorStyle': {'rgbColor': {'red': 1, 'green': 1, 'blue': 1}}},
#   'spreadsheetTheme': {'primaryFontFamily': 'Arial',
#    'themeColors': [{'colorType': 'TEXT', 'color': {'rgbColor': {}}},
#     {'colorType': 'BACKGROUND',
#      'color': {'rgbColor': {'red': 1, 'green': 1, 'blue': 1}}},
# ...

# %%
obk = gc.open_by_key(spreadsheet_key)
obk
# Out:
# <Spreadsheet 'Internship Details (Responses)' Sheets:1>

# %%
url = 'https://docs.google.com/spreadsheets/d/18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM/edit?usp=sharing'
obu = gc.open_by_key(url)
obu
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-22-cafee8045894> in <module>
#       1 url = 'https://docs.google.com/spreadsheets/d/18eQ5K7B-A1XLxmcy-W_ZlZ9ddDMnxhaIqzyHn0XDDOM/edit?usp=sharing'
# ----> 2 obu = gc.open_by_key(url)
#       3 obu
#
# ~\anaconda3\lib\site-packages\pygsheets\client.py in open_by_key(self, key)
#     157         :raises pygsheets.SpreadsheetNotFound:  The given spreadsheet ID was not found.
#     158         """
# --> 159         response = self.sheet.get(key,
#     160                                   fields='properties,sheets/properties,spreadsheetId,namedRanges',
#     161                                   includeGridData=False)
#
# ~\anaconda3\lib\site-packages\pygsheets\sheet.py in get(self, spreadsheet_id, **kwargs)
#     162         if 'includeGridData' not in kwargs:
#     163             kwargs['includeGridData'] = True
# ...
