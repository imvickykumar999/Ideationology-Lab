# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Numeric

# %%
a = 3

# %%
a
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
b = 3.14

# %%
b
# Out:
# 3.14

# %%
type(b)
# Out:
# float

# %%
c = 'python'

# %%
c
# Out:
# 'python'

# %%
type(c)
# Out:
# str

# %%
c[0]
# Out:
# 'p'

# %%
len(c)
# Out:
# 6

# %%
c[-1]
# Out:
# 'n'

# %%
c[-2]
# Out:
# 'o'

# %%
c[0:4]
# Out:
# 'pyth'

# %%
c
# Out:
# 'python'

# %%
c[0:4:2]
# Out:
# 'pt'

# %%
d = '123456789'
d[0:9:2]
# Out:
# '13579'

# %%
e = 'abcdefghijklmnopqrstuvwxyz'

# %%
type(e)
# Out:
# str

# %%
f = [1, 2, 3, 'a']

# %%
f
# Out:
# [1, 2, 3, 'a']

# %%
type(f)
# Out:
# list

# %%
len(f)
# Out:
# 4

# %%
f[0]
# Out:
# 1

# %%
type(f[-1])
# Out:
# str

# %%
f.append(6)

# %%
f
# Out:
# [1, 2, 3, 'a', 6]

# %%
f.pop()
# Out:
# 6

# %%
f
# Out:
# [1, 2, 3, 'a']

# %%
g = (1, 2, 3)

# %%
g
# Out:
# (1, 2, 3)

# %%
type(g)
# Out:
# tuple

# %%
g.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d9ba84ef1e55> in <module>
# ----> 1 g.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
g.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b40edc6c608f> in <module>
# ----> 1 g.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
h = [1, 2, 3, 'hi', ['a', g]]

# %%
a = (1, 2, 3, 'hello', 3.14)

# %%
a
# Out:
# (1, 2, 3, 'hello', 3.14)

# %%
h
# Out:
# [1, 2, 3, 'hi', ['a', (1, 2, 3)]]

# %%
type(h)
# Out:
# list

# %%
h[-1]
# Out:
# ['a', (1, 2, 3)]

# %%
h[-1][-1]
# Out:
# (1, 2, 3)

# %%
type(h[-1])
# Out:
# list

# %%
com = 1 + 7j

# %%
com
# Out:
# (1+7j)

# %%
type(com)
# Out:
# complex

# %%
type(4j)
# Out:
# complex

# %%
h = True

# %%
h
# Out:
# True

# %%
type(h)
# Out:
# bool

# %%
k = False

# %%
k
# Out:
# False

# %%
type(k)
# Out:
# bool

# %%
h and k
# Out:
# False

# %%
h or k
# Out:
# True

# %%
int(h)
# Out:
# 1

# %%
float(k)
# Out:
# 0.0

# %%
bool(1)
# Out:
# True

# %%
bool(8)
# Out:
# True

# %%
bool('hi')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool([1, 3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
n = {1, 2, 3, 2, 5, 1, 2}

# %%
n
# Out:
# {1, 2, 3, 5}

# %%
m = [1, 2, 3, 4, 3, 2, 6]

# %%
m
# Out:
# [1, 2, 3, 4, 3, 2, 6]

# %%
set(m)
# Out:
# {1, 2, 3, 4, 6}

# %%
1 in set(m)
# Out:
# True

# %%
8 in set(m)
# Out:
# False
