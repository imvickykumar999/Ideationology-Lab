# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests

user = 'CSSEGISandData'
gurl = f'https://github.com/{user}'

r = requests.get(gurl)
soup = BeautifulSoup(r.content, 'html5lib')

a = soup.findAll('rect', attrs = {'class':'ContributionCalendar-day'})
x = []
y = []

for i in a:
    try:
        x.append(i['data-date'])
        y.append(int(i['data-count']))
    except:
        pass
    
x1 = x[::-1][:30][::-1]
y1 = y[::-1][:30][::-1]

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10,3))
xpoints = np.array(x1)
ypoints = np.array(y1)

plt.xticks(rotation=90)
plt.grid()

plt.plot(xpoints, ypoints)
plt.show()
fig.savefig(f'user/{user}.png')

# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests

url = 'https://www.instagram.com/imvickykumar999/'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
# m = soup.find_all(['meta'])
a = soup.find('meta', attrs = {'name':'description'}) 
d = a['content']
l = d.split(',')
l
# Out:
# ['437 Followers',
#  ' 850 Following',
#  ' 26 Posts - See Instagram photos and videos from Vicky Kumar (@imvickykumar999)']

# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests

audio_id = '355319102737557'
url = f'https://www.instagram.com/reels/audio/{audio_id}/'

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js not-logged-in client-root" lang="en"><head>
#         <meta charset="utf-8"/>
#         <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#
#         <title>
# Instagram
# </title>
#
#
#         <meta content="noimageindex, noarchive" name="robots"/>
#         <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#         <meta content="yes" name="mobile-web-app-capable"/>
#         <meta content="#ffffff" name="theme-color"/>
#         <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover" id="viewport" name="viewport"/>
#         <link href="/data/manifest.json" rel="manifest"/>
#
#         <link as="style" crossorigin="anonymous" href="/static/bundles/metro/ConsumerUICommons.css/f06a8c5240e0.css" rel="preload" type="text/css"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/metro/Consumer.css/71d087b2ab18.css" rel="preload" type="text/css"/>
# ...

# %%
a = soup.findAll('div') 
a
# Out:
# [<div id="react-root">
#
#
# ...

# %%
aink = 'https://video.fjai3-1.fna.fbcdn.net/v/t39.12897-2/269675988_1647799278904701_8193296614520036417_n.m4a?_nc_cat=101&ccb=1-5&_nc_sid=02c1ff&_nc_ohc=Nvd_-w86T6kAX8bPXBs&_nc_ad=z-m&_nc_cid=1012&_nc_ht=video.fjai3-1.fna&oh=00_AT-O_cVBUUaLtFPcL3q3mP1zxhp7G3v2Ode4_CFuz0dj0g&oe=61F0ACA2' 
print(aink)
# Out:
# https://video.fjai3-1.fna.fbcdn.net/v/t39.12897-2/269675988_1647799278904701_8193296614520036417_n.m4a?_nc_cat=101&ccb=1-5&_nc_sid=02c1ff&_nc_ohc=Nvd_-w86T6kAX8bPXBs&_nc_ad=z-m&_nc_cid=1012&_nc_ht=video.fjai3-1.fna&oh=00_AT-O_cVBUUaLtFPcL3q3mP1zxhp7G3v2Ode4_CFuz0dj0g&oe=61F0ACA2

# %%
bink = 'https://video-del1-1.xx.fbcdn.net/v/t39.12897-2/271996412_475716780581907_8268156885234070493_n.m4a?_nc_cat=102&ccb=1-5&_nc_sid=02c1ff&_nc_ohc=5aQkpM_nRHsAX-aDwji&_nc_ad=z-m&_nc_cid=1012&_nc_ht=video-del1-1.xx&oh=00_AT-HmzEsuLkXx0pP2-1BNh7EBUkUbZSLDFco3ijJB_5V0Q&oe=61EFE051' 
print(bink)
# Out:
# https://video-del1-1.xx.fbcdn.net/v/t39.12897-2/271996412_475716780581907_8268156885234070493_n.m4a?_nc_cat=102&ccb=1-5&_nc_sid=02c1ff&_nc_ohc=5aQkpM_nRHsAX-aDwji&_nc_ad=z-m&_nc_cid=1012&_nc_ht=video-del1-1.xx&oh=00_AT-HmzEsuLkXx0pP2-1BNh7EBUkUbZSLDFco3ijJB_5V0Q&oe=61EFE051

# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests

user = 'imvickykumar999'
gurl = f'https://github.com/{user}'

r = requests.get(gurl)
soup = BeautifulSoup(r.content, 'html5lib')
# soup

# %%
a = soup.findAll('span', attrs = {'class':'text-bold color-fg-default'})
a
# Out:
# [<span class="text-bold color-fg-default">93</span>,
#  <span class="text-bold color-fg-default">452</span>]

# %%
f = f'''
Followers = {a[0].text}
Following = {a[1].text}
'''
print(f)
# Out:
# Followers = 93
# Following = 452

# %%
b = soup.findAll('span', attrs = {'class':'Counter'})
b
# Out:
# [<span class="Counter" data-view-component="true" title="311">311</span>,
#  <span class="Counter" data-view-component="true" hidden="hidden" title="0">0</span>,
#  <span class="Counter" data-view-component="true" hidden="hidden" title="0">0</span>,
#  <span class="Counter" data-view-component="true" title="462">462</span>,
#  <span class="Counter" data-view-component="true" title="311">311</span>,
#  <span class="Counter" data-view-component="true" hidden="hidden" title="0">0</span>,
#  <span class="Counter" data-view-component="true" hidden="hidden" title="0">0</span>,
#  <span class="Counter" data-view-component="true" title="462">462</span>]

# %%
g = f'''
Repositories = {b[0].text}
'''
print(g)
# Out:
# Repositories = 311

# %%
from instabot import Bot
import getpass
bot = Bot()

def upload(user, passwd, path, cap):
    bot.login(username = user, password = passwd)
    up = bot.upload_photo(path, caption = cap)
    return up

user = input('Enter Username : ')
passwd = getpass.getpass('Enter Password : ')

path = input('Photo name.jpg : ')
cap = input('Enter Caption : ')

upload(user, passwd, path, cap)
# Out:
# 2022-01-22 16:20:34,685 - INFO - Instabot version: 0.117.0 Started
# Enter Username : _____.___alone___._____
# Enter Password : ········
# Photo name.jpg : imvickykumar999.jpeg
# Enter Caption : 🔥This image is uploaded using python code✨
# 2022-01-22 16:20:56,944 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2022-01-22 16:21:01,218 - INFO - Logged-in successfully as '_____.___alone___._____'!
# 2022-01-22 16:21:01,219 - INFO - LOGIN FLOW! Just logged-in: True
# 2022-01-22 16:21:17,669 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2022-01-22 16:21:17,675 - INFO - Full Response: <Response [404]>
# 2022-01-22 16:21:17,678 - INFO - Response Text: <!DOCTYPE html>
# <html lang="en" class="no-js logged-in client-root touch">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>
# Instagram
# </title>
#
#
#         <meta name="robots" content="noimageindex, noarchive">
# ...

# %%
uploaded = {'taken_at': 1642848702,
'pk': 2756737183448879866,
'id': '2756737183448879866_45213970613',
'device_timestamp': 1642848687923,
'media_type': 1,
'code': 'CZB5dzOlNL6Ss97xj1DxgyQ0DWd66UUVfqCtGY0',
'client_cache_key': 'Mjc1NjczNzE4MzQ0ODg3OTg2Ng==.2',
'filter_type': 0,
'is_unified_video': False,
'user': {'pk': 45213970613,
'username': '_____.___alone___._____',
'full_name': 'alone',
'is_private': True,
'profile_pic_url': 'https://scontent-del1-1.cdninstagram.com/v/t51.2885-19/s150x150/272073209_4766996536717414_6751764571758329725_n.jpg?_nc_ht=scontent-del1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=SANNA4Kg0PwAX-yZR3N&edm=ACqnv0EBAAAA&ccb=7-4&oh=00_AT8nFw02eE7gB138hxC493WJbM1Tk-uvuM0jIt0xAYHZ5A&oe=61F2C357&_nc_sid=9ec724',
'profile_pic_id': '2753236639209031150_45213970613',
'has_anonymous_profile_picture': False,
'can_boost_post': False,
'can_see_organic_insights': False,
'show_insights_terms': False,
'reel_auto_archive': 'on',
'is_unpublished': False,
'allowed_commenter_type': 'any',
'has_highlight_reels': False,
'interop_messaging_user_fbid': 17846208059506614,
'fbid_v2': 17841445198401746},
'can_viewer_reshare': True,
'caption_is_edited': False,
'like_and_view_counts_disabled': False,
'commerciality_status': 'not_commercial',
'is_paid_partnership': False,
'is_visual_reply_commenter_notice_enabled': True,
'comment_likes_enabled': False,
'comment_threading_enabled': False,
'has_more_comments': False,
'max_num_visible_preview_comments': 2,
'preview_comments': [],
'can_view_more_preview_comments': False,
'comment_count': 0,
'hide_view_all_comment_entrypoint': False,
'image_versions2': {'candidates': [{'width': 720,
'height': 720,
'url': 'https://scontent-del1-1.cdninstagram.com/v/t51.2885-15/e35/272188266_163378026024949_8974429476679702783_n.jpg?_nc_ht=scontent-del1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=lubbxmCOCl4AX_ud8Ye&edm=ACqnv0EBAAAA&ccb=7-4&ig_cache_key=Mjc1NjczNzE4MzQ0ODg3OTg2Ng%3D%3D.2-ccb7-4&oh=00_AT-0eVDzftQX2b87jmPgGpAgcgvPBeThbmcalWtgXPiTBA&oe=61F25187&_nc_sid=9ec724',
'scans_profile': 'e35',
'estimated_scans_sizes': [9243,
18487,
27731,
36975,
46218,
55786,
67533,
75210,
83194]},
{'width': 360,
'height': 360,
'url': 'https://scontent-del1-1.cdninstagram.com/v/t51.2885-15/e35/s360x360/272188266_163378026024949_8974429476679702783_n.jpg?_nc_ht=scontent-del1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=lubbxmCOCl4AX_ud8Ye&edm=ACqnv0EBAAAA&ccb=7-4&ig_cache_key=Mjc1NjczNzE4MzQ0ODg3OTg2Ng%3D%3D.2-ccb7-4&oh=00_AT8txgG9obIouyXcg_HPWPsGZ-pCO8-Z0ePMl4o15ZIZ-g&oe=61F2CF55&_nc_sid=9ec724',
'scans_profile': 'e35',
'estimated_scans_sizes': [3347,
6694,
10041,
13388,
16736,
20892,
269824,
30125,
30125]}]},
'original_width': 720,
'original_height': 720,
'photo_of_you': False,
'can_see_insights_as_brand': False,
'caption': {'pk': 17938060210844339,
'user_id': 45213970613,
'text': '🔥This image is uploaded using python code✨',
'type': 1,
'created_at': 1642848703,
'created_at_utc': 1642848703,
'content_type': 'comment',
'status': 'Active',
'bit_flags': 0,
'did_report_as_spam': False,
'share_enabled': False,
'user': {'pk': 45213970613,
'username': '_____.___alone___._____',
'full_name': 'alone',
'is_private': True,
'profile_pic_url': 'https://scontent-del1-1.cdninstagram.com/v/t51.2885-19/s150x150/272073209_4766996536717414_6751764571758329725_n.jpg?_nc_ht=scontent-del1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=SANNA4Kg0PwAX-yZR3N&edm=ACqnv0EBAAAA&ccb=7-4&oh=00_AT8nFw02eE7gB138hxC493WJbM1Tk-uvuM0jIt0xAYHZ5A&oe=61F2C357&_nc_sid=9ec724',
'profile_pic_id': '2753236639209031150_45213970613',
'has_anonymous_profile_picture': False,
'can_boost_post': False,
'can_see_organic_insights': False,
'show_insights_terms': False,
'reel_auto_archive': 'on',
'is_unpublished': False,
'allowed_commenter_type': 'any',
'has_highlight_reels': False,
'interop_messaging_user_fbid': 17846208059506614,
'fbid_v2': 17841445198401746},
'is_covered': False,
'media_id': 2756737183448879866,
'private_reply_status': 0},
'fb_user_tags': {'in': []},
'can_viewer_save': True,
'organic_tracking_token': '',
'sharing_friction_info': {'should_have_sharing_friction': False,
'bloks_app_url': None},
'comment_inform_treatment': {'should_have_inform_treatment': False,
'text': ''},
'product_type': 'feed',
'is_in_profile_grid': False,
'profile_grid_control_enabled': False,
'deleted_reason': 0,
'integrity_review_decision': 'pending',
'music_metadata': {'music_canonical_id': '0',
'audio_type': None,
'music_info': None,
'original_sound_info': None},
'post_friction_info': {'should_show_post_friction': False,
'post_friction_reason': 'none'}}

# %%
uploaded.keys()
# Out:
# dict_keys(['taken_at', 'pk', 'id', 'device_timestamp', 'media_type', 'code', 'client_cache_key', 'filter_type', 'is_unified_video', 'user', 'can_viewer_reshare', 'caption_is_edited', 'like_and_view_counts_disabled', 'commerciality_status', 'is_paid_partnership', 'is_visual_reply_commenter_notice_enabled', 'comment_likes_enabled', 'comment_threading_enabled', 'has_more_comments', 'max_num_visible_preview_comments', 'preview_comments', 'can_view_more_preview_comments', 'comment_count', 'hide_view_all_comment_entrypoint', 'image_versions2', 'original_width', 'original_height', 'photo_of_you', 'can_see_insights_as_brand', 'caption', 'fb_user_tags', 'can_viewer_save', 'organic_tracking_token', 'sharing_friction_info', 'comment_inform_treatment', 'product_type', 'is_in_profile_grid', 'profile_grid_control_enabled', 'deleted_reason', 'integrity_review_decision', 'music_metadata', 'post_friction_info'])

# %%
uploaded['user']
# Out:
# {'pk': 45213970613,
#  'username': '_____.___alone___._____',
#  'full_name': 'alone',
#  'is_private': True,
#  'profile_pic_url': 'https://scontent-del1-1.cdninstagram.com/v/t51.2885-19/s150x150/272073209_4766996536717414_6751764571758329725_n.jpg?_nc_ht=scontent-del1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=SANNA4Kg0PwAX-yZR3N&edm=ACqnv0EBAAAA&ccb=7-4&oh=00_AT8nFw02eE7gB138hxC493WJbM1Tk-uvuM0jIt0xAYHZ5A&oe=61F2C357&_nc_sid=9ec724',
#  'profile_pic_id': '2753236639209031150_45213970613',
#  'has_anonymous_profile_picture': False,
#  'can_boost_post': False,
#  'can_see_organic_insights': False,
#  'show_insights_terms': False,
#  'reel_auto_archive': 'on',
#  'is_unpublished': False,
#  'allowed_commenter_type': 'any',
#  'has_highlight_reels': False,
#  'interop_messaging_user_fbid': 17846208059506614,
#  'fbid_v2': 17841445198401746}

# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import numpy as np

user1 = 'imvickykumar999'
user2 = 'ayu4tor'

def fetch_data(user):
    gurl = f'https://github.com/{user}'
    r = requests.get(gurl)
    soup = BeautifulSoup(r.content, 'html5lib')

    a = soup.findAll('rect', attrs = {'class':'ContributionCalendar-day'})
    x = []
    y = []

    for i in a:
        try:
            x.append(i['data-date'])
            y.append(int(i['data-count']))
        except:
            pass

    x1 = x[::-1][:30][::-1]
    y1 = y[::-1][:30][::-1]
    
    xpoints = np.array(x1)
    ypoints = np.array(y1)
    return xpoints, ypoints

fig = plt.figure(figsize=(10,3))
plt.xticks(rotation=90)
plt.grid()

plt.plot(fetch_data(user1)[0], fetch_data(user1)[1], label=user1)
plt.plot(fetch_data(user2)[0], fetch_data(user2)[1], label=user2)

plt.legend()
plt.show()
fig.savefig(f'user/{user1}+{user2}.png')

# %%
from PIL import Image

def make_square(im, min_size=256, fill_color=(0, 0, 0, 0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

test_image = Image.open(f'user/{user1}+{user2}.png')
new_image = make_square(test_image)
new_image.save(f'user/{user1}+{user2}+squared.png')

# %%
from instabot import Bot
import getpass
bot = Bot()

def upload(user, passwd, path, cap):
    bot.login(username = user, password = passwd)
    up = bot.upload_photo(path, caption = cap)
    return up

user = '_____.___alone___._____'
passwd = getpass.getpass('Enter Password : ')

path = f'user/{user1}+{user2}+squared.png'
cap = '🔥This image is uploaded using python code✨'

upload(user, passwd, path, cap)
# Out:
# 2022-01-22 17:26:02,557 - INFO - Instabot version: 0.117.0 Started
# Enter Password : ········
# 2022-01-22 17:26:13,089 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2022-01-22 17:26:17,747 - INFO - Logged-in successfully as '_____.___alone___._____'!
# 2022-01-22 17:26:17,749 - INFO - LOGIN FLOW! Just logged-in: True
# 2022-01-22 17:26:38,806 - WARNING - HTTPSConnectionPool(host='i.instagram.com', port=443): Max retries exceeded with url: /api/v1/qe/sync/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000027240FEC1C0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
# 2022-01-22 17:26:55,329 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2022-01-22 17:26:55,332 - INFO - Full Response: <Response [404]>
# ...

# %%
# !pip install bs4

from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import numpy as np

user1 = 'imvickykumar999'
user2 = 'ayu4tor'

def fetch_data(user):
    gurl = f'https://github.com/{user}'
    r = requests.get(gurl)
    soup = BeautifulSoup(r.content, 'html5lib')

    a = soup.findAll('rect', attrs = {'class':'ContributionCalendar-day'})
    x = []
    y = []

    for i in a:
        try:
            x.append(i['data-date'])
            y.append(int(i['data-count']))
        except:
            pass

    x1 = x[::-1][:30][::-1]
    y1 = y[::-1][:30][::-1]

    xpoints = np.array(x1)
    ypoints = np.array(y1)
    return xpoints, ypoints

fig = plt.figure(figsize=(10,3))
plt.xticks(rotation=90)
plt.grid()

plt.plot(fetch_data(user1)[0], fetch_data(user1)[1], label=user1)
plt.plot(fetch_data(user2)[0], fetch_data(user2)[1], label=user2)

plt.legend()
# plt.show()
fig.savefig(f'user/{user1}+{user2}.png')

from PIL import Image

def make_square(im, min_size=256, fill_color=(0, 0, 0, 0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

test_image = Image.open(f'user/{user1}+{user2}.png')
new_image = make_square(test_image)
new_image.save('squared.png')

from instabot import Bot
import getpass
bot = Bot()

def upload(user, passwd, path, cap):
    bot.login(username = user, password = passwd)
    up = bot.upload_photo(path, caption = cap)
    return up

user = '_____.___alone___._____'
passwd = getpass.getpass('Enter Password : ')

path = 'squared.png'
cap = '🔥This image is uploaded using python code✨'

upload(user, passwd, path, cap)
# Out:
# 2022-01-22 17:45:06,989 - INFO - Instabot version: 0.117.0 Started
# 2022-01-22 17:45:06,995 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2022-01-22 17:45:10,574 - INFO - Logged-in successfully as '_____.___alone___._____'!
# 2022-01-22 17:45:10,575 - INFO - LOGIN FLOW! Just logged-in: True
# 2022-01-22 17:45:22,804 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2022-01-22 17:45:22,807 - INFO - Full Response: <Response [404]>
# 2022-01-22 17:45:22,809 - INFO - Response Text: <!DOCTYPE html>
# <html lang="en" class="no-js logged-in client-root touch">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#         <title>
# Instagram
# </title>
#
#
#         <meta name="robots" content="noimageindex, noarchive">
#         <meta name="apple-mobile-web-app-status-bar-style" content="default">
#         <meta name="mobile-web-app-capable" content="yes">
# ...
