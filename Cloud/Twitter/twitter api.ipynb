# %% [markdown]
# ##### https://t.co/ZAiOOupBpR

# %% [markdown]
# # [How to Make a Twitter Bot in Python With Tweepy](https://realpython.com/twitter-bot-python-tweepy/)
#
# -----------------------------------------
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## https://twitter.com/imvickykumar999

# %%
# !pip install tweepy

# %% [markdown]
# # [ref_get](https://console.firebase.google.com/u/0/project/ideationology-4c639/database/ideationology-4c639-default-rtdb/data)

# %%
import tweepy, os
import pandas as pd
# ref_get : it contain data from firebase

# Authenticate to Twitter
# https://developer.twitter.com/en/portal/projects/1487176177085255682/apps/23232500/keys

CONSUMER_KEY = ref_get['CONSUMER_KEY']
CONSUMER_SECRET = ref_get['CONSUMER_SECRET']
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

ACCESS_TOKEN = ref_get['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = ref_get['ACCESS_TOKEN_SECRET']
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

API = tweepy.API(auth)
try:
    API.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
API
# Out:
# Authentication OK

# %%
timeline = API.home_timeline()
# timeline

# %%
timeline[0].user._json
# Out:
# {'id': 1487141902294081536,
#  'id_str': '1487141902294081536',
#  'name': 'Vicky Kumar',
#  'screen_name': 'imvickykumar999',
#  'location': 'JAIPUR',
#  'description': 'i do magic with python.',
#  'url': 'https://t.co/ZAiOOupBpR',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/ZAiOOupBpR',
#      'expanded_url': 'https://imvickykumar999.herokuapp.com/vickstube?vix=eYq7WapuDLU#vickscroll',
#      'display_url': 'imvickykumar999.herokuapp.com/vickstube?vix=…',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1,
#  'friends_count': 5,
#  'listed_count': 0,
#  'created_at': 'Fri Jan 28 19:14:04 +0000 2022',
#  'favourites_count': 4,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 3,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
# ...

# %%
txt = timeline[0].text
print(txt)
# Out:
# 24 industries to be disrupted by AI: an infographic https://t.co/MAdEYc8bDk

# %%
link = txt[-23:]
print(link)
# Out:
# https://t.co/MAdEYc8bDk

# %%
for tweet in timeline:
#     print(tweet)
    print(f"{tweet.user.name} --> said, {tweet.text}", end='\n\n')
# Out:
# Vicky Kumar --> said, 24 industries to be disrupted by AI: an infographic https://t.co/MAdEYc8bDk
#
# Vicky Kumar --> said, @realpython thanks for article, it helped me in using twitter api
#
# Vicky Kumar --> said, RT @realpython: 🐍💌 Python's list comprehensions are awesome! (Get the full series at https://t.co/4N1PnS0akJ) https://t.co/cEnV9EibCM
#
# Google --> said, Over the past five years, @GoogleOrg and Googlers have given $2B to causes and communities around the world. As we… https://t.co/xrLSgj1Cz8
#
# Narendra Modi --> said, India’s pride and sporting champion @manikabatra_TT wonderfully shared her experience of visiting the National War… https://t.co/e8dfqQR07X
#
# Narendra Modi --> said, Presented the Chadar which shall be offered at the Ajmer Sharif Dargah on the Urs of Khwaja Moinuddin Chishti. https://t.co/SJhObXNhRA
#
# ...

# %%
tweets = API.home_timeline(count=10)
tweet = tweets[0]
print(f"Liking tweet {tweet.id} of {tweet.author.name}")
# api.create_favorite(tweet.id)
# Out:
# Liking tweet 1488955900362690570 of Vicky Kumar

# %%
for i in API.home_timeline(count=50):
    an = i.author.name
    print(an)
# Out:
# Vicky Kumar
# Vicky Kumar
# Vicky Kumar
# Google
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Google
# Google
# Google
# Google
# Google
# Google
# Google
# Narendra Modi
# Google
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Google
# Google
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi
# Narendra Modi

# %%
for tweet in API.search_tweets(q="imvickykumar999", lang="en"):
    print(f"{tweet.user.name}:{tweet.text}")
# Out:
# Vicky Kumar:@realpython thanks for article, it helped me in using twitter api
# Vicky Kumar:RT @realpython: 🐍💌 Python's list comprehensions are awesome! (Get the full series at https://t.co/4N1PnS0akJ) https://t.co/cEnV9EibCM

# %%
# https://publish.twitter.com/?query=https%3A%2F%2Ftwitter.com%2Fimvickykumar999%2Fstatus%2F1488955900362690570&widget=Tweet

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">24 industries to be disrupted by AI: an infographic <a href="https://t.co/MAdEYc8bDk">https://t.co/MAdEYc8bDk</a></p>&mdash; Vicky Kumar (@imvickykumar999) <a href="https://twitter.com/imvickykumar999/status/1488955900362690570?ref_src=twsrc%5Etfw">February 2, 2022</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %%
tweets = api.mentions_timeline()
for tweet in tweets:
    tweet.favorite()
    tweet.user.follow()
tweets
# Out:
# []

# %%
for tweet in tweepy.Cursor(api.home_timeline).items(100):
    print(f"{tweet.user.name} said: {tweet.text}")
# Out:
# Vicky Kumar said: 24 industries to be disrupted by AI: an infographic https://t.co/MAdEYc8bDk
# Vicky Kumar said: @realpython thanks for article, it helped me in using twitter api
# Vicky Kumar said: RT @realpython: 🐍💌 Python's list comprehensions are awesome! (Get the full series at https://t.co/4N1PnS0akJ) https://t.co/cEnV9EibCM
# Google said: Over the past five years, @GoogleOrg and Googlers have given $2B to causes and communities around the world. As we… https://t.co/xrLSgj1Cz8
# Narendra Modi said: India’s pride and sporting champion @manikabatra_TT wonderfully shared her experience of visiting the National War… https://t.co/e8dfqQR07X
# Narendra Modi said: Presented the Chadar which shall be offered at the Ajmer Sharif Dargah on the Urs of Khwaja Moinuddin Chishti. https://t.co/SJhObXNhRA
# Narendra Modi said: Urbanisation is a reality of our times and this year’s Budget offers innovative policy measures to boost ‘Ease of L… https://t.co/qssJTVVGII
# ...

# %%
# https://developer.twitter.com/en/docs/apps/app-permissions

# api.update_status("Test tweet from Tweepy Python")

# %%
# api.update_status("Test tweet from Tweepy Python")

# %%
# user = api.get_user(user_id="MikezGarcia")

# print("User details:")
# print(user.name)
# print(user.description)
# print(user.location)

# print("Last 20 Followers:")
# for follower in user.followers():
#     print(follower.name)

# %%
# API.create_friendship(user_id="realpython")

# %% [markdown]
# ### [Twitter API v1.1 Reference](https://docs.tweepy.org/en/v4.1.0/api.html#tweepy.API.get_user)

# %%
API.get_settings()
# Out:
# {'protected': False,
#  'screen_name': 'imvickykumar999',
#  'always_use_https': True,
#  'use_cookie_personalization': True,
#  'sleep_time': {'enabled': False, 'end_time': None, 'start_time': None},
#  'geo_enabled': False,
#  'language': 'en',
#  'discoverable_by_email': True,
#  'discoverable_by_mobile_phone': True,
#  'display_sensitive_media': False,
#  'allow_contributor_request': 'all',
#  'allow_dms_from': 'following',
#  'allow_dm_groups_from': 'following',
#  'translator_type': 'none'}

# %%
fav = API.get_favorites()
fav
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001B1580907F0>, _json={'created_at': 'Wed Feb 02 17:01:02 +0000 2022', 'id': 1488920406996176905, 'id_str': '1488920406996176905', 'text': 'Over the past five years, @GoogleOrg and Googlers have given $2B to causes and communities around the world. As we… https://t.co/xrLSgj1Cz8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Googleorg', 'name': 'Google.org', 'id': 2499289070, 'id_str': '2499289070', 'indices': [26, 36]}], 'urls': [{'url': 'https://t.co/xrLSgj1Cz8', 'expanded_url': 'https://twitter.com/i/web/status/1488920406996176905', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20536157, 'id_str': '20536157', 'na
# ...

# %%
len(fav)
# Out:
# 8

# %%
for i in fav:
    try:
        u = i._json['entities']['urls'][0]['url']
        print(u)
    except:
        pass
# Out:
# https://t.co/xrLSgj1Cz8
# https://t.co/qssJTVVGII
# https://t.co/RuoQphdscy
# https://t.co/4N1PnS0akJ

# %%
API.get_retweets_of_me()
# Out:
# []

# %%
API.retweet(id = 956921175027875840)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# <ipython-input-316-3aea78112767> in <module>
# ----> 1 API.retweet(id = 956921175027875840)
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in retweet(self, id, **kwargs)
#     991         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/post-and-engage/api-reference/post-statuses-retweet-id
#     992         """
# --> 993         return self.request(
#     994             'POST', f'statuses/retweet/{id}', endpoint_parameters=(
#     995                 'trim_user',
#
# ...

# %%
# ==================================

# %% [markdown]
# ### [Earth Data Analytics Online Certificate](https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/)

# %%
import os
import tweepy as tw
import pandas as pd

# %%
api = tw.API(auth, wait_on_rate_limit=True)
api

# %%
# Post a tweet from Python
# api.update_status("Look, I'm tweeting from #Python in my #earthanalytics class! @EarthLabCU")
# Your tweet has been posted!

# %%
# Define the search term and the date_since date as variables
search_words = "#wildfires"
date_since = "2018-11-16"

new_search = search_words + " -filter:retweets"
new_search
# Out:
# '#wildfires -filter:retweets'

# %%
# https://stackoverflow.com/a/69332706/11493297

# Collect tweets
tweets = tw.Cursor(api.search_tweets,
              q=search_words,
              lang="en",
#               since=date_since
            ).items(5)
tweets

# %%
tap = []
users_locs = []

# Iterate and print tweets
for tweet in tweets:
#     print(tweet.text)
    tap.append(tweet.text)
    users_locs.append([tweet.user.screen_name, tweet.user.location])

# %%
tap
# Out:
# ['RT @iiiorg: Dr. Craig Clements, a Professor of Meteorology at @SJSU &amp; the Director of SJSU’s @wildfirecenter, has been appointed a non-resi…',
#  'RT @FireAviation: The 747 formerly known as the #Supertanker when it delivered 19,000 gallons of retardant on #wildfires, was spotted recen…',
#  'RT @iiiorg: Dr. Craig Clements, a Professor of Meteorology at @SJSU &amp; the Director of SJSU’s @wildfirecenter, has been appointed a non-resi…',
#  'RT @FireAviation: The 747 formerly known as the #Supertanker when it delivered 19,000 gallons of retardant on #wildfires, was spotted recen…',
#  'RT @VeePollock: CULL by @FineArtNCL @UtaKogelsberger on Marriott LA Live, 900 West Olympic Boulevard 01/02/2022-28/02/2022 launches Fire Co…']

# %%
users_locs
# Out:
# [['LorettaWorters', "Author, Women's Advocate"],
#  ['Koffice14', 'Vantaa, FINLAND'],
#  ['III_SeanK', 'New York, NY'],
#  ['Richard31790916', ''],
#  ['HaSSResNCL', 'Newcastle Upon Tyne, England']]

# %%
tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', "location"])
tweet_text
# Out:
#               user                      location
# 0   LorettaWorters      Author, Women's Advocate
# 1        Koffice14               Vantaa, FINLAND
# 2        III_SeanK                  New York, NY
# 3  Richard31790916
# 4       HaSSResNCL  Newcastle Upon Tyne, England

# %%
tweet_text.to_csv('wildfires.csv')

# %%
# ==========================================

# %% [markdown]
# ### [An Extensive Guide to collecting tweets from Twitter API v2 for academic research using Python 3](https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a)

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
# os.environ['TOKEN'] = '*********'

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "xbox lang:en"
start_time = "2021-03-01T00:00:00.000Z"
end_time = "2021-03-31T00:00:00.000Z"
max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)
url
# Out:
# ('https://api.twitter.com/2/tweets/search/all',
#  {'query': 'xbox lang:en',
#   'start_time': '2021-03-01T00:00:00.000Z',
#   'end_time': '2021-03-31T00:00:00.000Z',
#   'max_results': 15,
#   'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
#   'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
#   'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
#   'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
#   'next_token': {}})

# %%
# json_response = connect_to_endpoint(url[0], headers, url[1])
# json_response

# %%
# ===========================================

# %% [markdown]
# ### [Accessing the Twitter API with Python](https://stackabuse.com/accessing-the-twitter-api-with-python/)

# %%
# import json

# # Enter your keys/secrets as strings in the following fields
# credentials = {}
# credentials['CONSUMER_KEY'] = refv['CONSUMER_KEY']
# credentials['CONSUMER_SECRET'] = refv['CONSUMER_SECRET']
# credentials['ACCESS_TOKEN'] = refv['ACCESS_TOKEN']
# credentials['ACCESS_SECRET'] = refv['ACCESS_SECRET']

# # Save the credentials object to file
# with open("twitter_credentials.json", "w") as file:
#     json.dump(credentials, file)

# %%
# !pip install twython

# %%
# Import the Twython class
from twython import Twython
import json

# Load credentials from json file
# with open("twitter_credentials.json", "r") as file:
#     creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'q': 'python',
        'result_type': 'popular',
        'count': 10,
        'lang': 'en',
        }

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['favorite_count'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='favorite_count', inplace=True, ascending=False)
df.head(5)
# Out:
#              user                            date  \
# 4         NordVPN  Mon Jan 31 21:55:00 +0000 2022
# 9       MIT_CSAIL  Mon Jan 31 17:00:02 +0000 2022
# 0          simonw  Wed Feb 02 01:53:25 +0000 2022
# 1  MarshallJulius  Tue Feb 01 12:12:00 +0000 2022
# 2   SecretNetwork  Tue Feb 01 19:03:05 +0000 2022
#
#                                                 text  favorite_count
# 4  #ITymology\nSpam (the term for unsolicited mes...            3882
# 9  Happy birthday to Python creator Guido van Ros...            2239
# 0  Whoa. https://t.co/RuoQphdscy runs a full Debi...            1009
# 1  Remembering Python icon Terry Jones, born toda...             447
# 2  Secret Python is live: a secret SDK + tooling ...             256

# %%
df.to_csv('python_tweets_search_python.csv')

# %%
dc = python_tweets.search(**{'q': 'python',
        'result_type': 'popular',
        'count': 2,
        'lang': 'en',
        })['statuses'][0]
dc
# Out:
# {'created_at': 'Wed Feb 02 01:53:25 +0000 2022',
#  'id': 1488691998307622915,
#  'id_str': '1488691998307622915',
#  'text': 'Whoa. https://t.co/RuoQphdscy runs a full Debian VM entirely in your browser via WebAssembly... and it ships with w… https://t.co/JjE32EJ8yp',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/RuoQphdscy',
#     'expanded_url': 'https://webvm.io/',
#     'display_url': 'webvm.io',
#     'indices': [6, 29]},
#    {'url': 'https://t.co/JjE32EJ8yp',
#     'expanded_url': 'https://twitter.com/i/web/status/1488691998307622915',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
# ...

# %%
dc.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
print(dc['text'][-23:])
# Out:
# https://t.co/JjE32EJ8yp

# %%
from twython import TwythonStreamer
import csv

# Filter out unwanted data
def process_tweet(tweet):
    d = {}
    d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    d['text'] = tweet['text']
    d['user'] = tweet['user']['screen_name']
    d['user_loc'] = tweet['user']['location']
    return d
    
    
# Create a class that inherits TwythonStreamer
class MyStreamer(TwythonStreamer):     

    # Received data
    def on_success(self, data):

        # Only collect tweets in English
        if data['lang'] == 'en':
            tweet_data = process_tweet(data)
            self.save_to_csv(tweet_data)

    # Problem with the API
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()
        
    # Save each tweet to csv file
    def save_to_csv(self, tweet):
        with open(r'saved_tweets.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(list(tweet.values()))

# %%
# Instantiate from our streaming class
stream = MyStreamer(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'], 
                    creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
# Start the stream
stream.statuses.filter(track='python')

# %%
import pandas as pd
tweets = pd.read_csv("saved_tweets.csv", encoding= 'unicode_escape')
tweets.head()
# Out:
#                                                   []  \
# 0  ['Assignments', 'calculus', 'homework', 'Homew...
# 1                                                 []
# 2                                  ['100DaysOfCode']
# 3  ['Infographic', 'SaaS', 'mobileapp', 'webappli...
# 4                                  ['100DaysOfCode']
#
#   RT @s0md3v: I created a golang-library to asses whether a given string is machine-generated or human readable! It works by checking bigrams
#   \
# 0  RT @porteressays: Pay us to do or write your \...
# 1  RT @ThinkerAspiring: They changed it "back" to...
# 2  RT @manvendra2702: Successfully completed Day ...
# 3  RT @forgeaheadio: #Infographic: Do you want to...
# 4  RT @manvendra2702: Successfully completed Day ...
#
#         lsoutenare          Paris, France
# 0  geraldmuvengei2                    NaN
# 1      TrollColors  Central Coast CA, USA
# 2      py_data_sci                    NaN
# 3          whopcod                 Turkey
# ...
