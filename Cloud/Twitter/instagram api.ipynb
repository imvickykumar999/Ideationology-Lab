# %%
url = 'https://www.instagram.com/imvickykumar999/?__a=1'
print(url)
# Out:
# https://www.instagram.com/imvickykumar999/?__a=1

# %%
import requests
r = requests.get(url)

# %%
import json
jar = json.loads(r.text)
jar
# Out:
# {'seo_category_infos': [['Beauty', 'beauty'],
#   ['Dance & Performance', 'dance_and_performance'],
#   ['Fitness', 'fitness'],
#   ['Food & Drink', 'food_and_drink'],
#   ['Home & Garden', 'home_and_garden'],
#   ['Music', 'music'],
#   ['Visual Arts', 'visual_arts']],
#  'logging_page_id': 'profilePage_7015147780',
#  'show_suggested_profiles': False,
#  'show_follow_dialog': False,
#  'graphql': {'user': {'biography': 'Hey Vicks 🍻\n🇮🇳 My Projects are my Imagination to turn into Reality.\n🎊 My Google Chat Bot coded in one night. ❤️\n😜👇',
#    'blocked_by_viewer': False,
#    'restricted_by_viewer': None,
#    'country_block': False,
#    'external_url': 'https://vixtest.herokuapp.com/',
#    'external_url_linkshimmed': 'https://l.instagram.com/?u=https%3A%2F%2Fvixtest.herokuapp.com%2F&e=ATPeDnUd7ARZiNIkZj5DlH6ODl2e_XuFHwCk9mFCzL1Y63YhT7cIFNej0Ua1TxXgmcPnNRJwz7MQImRw&s=1',
#    'edge_followed_by': {'count': 434},
#    'fbid': '17841407073406893',
#    'followed_by_viewer': False,
#    'edge_follow': {'count': 885},
#    'follows_viewer': False,
#    'full_name': 'Vicky Kumar',
#    'has_ar_effects': False,
#    'has_clips': True,
#    'has_guides': False,
#    'has_channel': False,
#    'has_blocked_viewer': False,
#    'highlight_reel_count': 0,
#    'has_requested_viewer': False,
#    'hide_like_and_view_counts': False,
#    'id': '7015147780',
#    'is_business_account': False,
#    'is_professional_account': False,
#    'is_embeds_disabled': False,
#    'is_joined_recently': False,
#    'business_address_json': None,
#    'business_contact_method': 'UNKNOWN',
#    'business_email': None,
#    'business_phone_number': None,
#    'business_category_name': None,
#    'overall_category_name': None,
#    'category_enum': None,
#    'category_name': None,
#    'is_private': True,
#    'is_verified': False,
#    'edge_mutual_followed_by': {'count': 0, 'edges': []},
#    'profile_pic_url': 'https://scontent-del1-2.cdninstagram.com/v/t51.2885-19/s150x150/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=scontent-del1-2.cdninstagram.com&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX-nhihF&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT_P71I-bFzSZ41lM95EfoJEqhDmlDjJSTCWq40Rdqnyng&oe=620926E6&_nc_sid=7bff83',
#    'profile_pic_url_hd': 'https://scontent-del1-2.cdninstagram.com/v/t51.2885-19/s320x320/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=scontent-del1-2.cdninstagram.com&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX-nhihF&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT-NdmT0j6V_Yqgq_KSc_WB10OnfKpWZFcunQ7yfPP5EHg&oe=6208CA9E&_nc_sid=7bff83',
#    'requested_by_viewer': False,
#    'should_show_category': False,
#    'should_show_public_contacts': False,
#    'username': 'imvickykumar999',
#    'connected_fb_page': None,
#    'pronouns': [],
#    'edge_felix_video_timeline': {'count': 4,
#     'page_info': {'has_next_page': False, 'end_cursor': ''},
#     'edges': []},
#    'edge_owner_to_timeline_media': {'count': 28,
#     'page_info': {'has_next_page': False, 'end_cursor': ''},
#     'edges': []},
#    'edge_saved_media': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []},
#    'edge_media_collections': {'count': 0,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': []},
#    'edge_related_profiles': {'edges': []}}},
#  'toast_content_on_load': None,
#  'show_view_shop': False,
#  'profile_pic_edit_sync_props': {'show_change_profile_pic_confirm_dialog': False,
#   'show_profile_pic_sync_reminders': False,
#   'identity_id': '',
#   'remove_profile_pic_header': None,
#   'remove_profile_pic_subtext': None,
#   'remove_profile_pic_confirm_cta': None,
#   'remove_profile_pic_cancel_cta': None,
#   'is_business_central_identity': False,
#   'change_profile_pic_actions_screen_header': ['C',
#    'h',
#    'a',
#    'n',
#    'g',
#    'e',
#    ' ',
#    'P',
#    'r',
#    'o',
#    'f',
#    'i',
#    'l',
#    'e',
#    ' ',
#    'P',
#    'h',
#    'o',
#    't',
#    'o'],
#   'change_profile_pic_actions_screen_subheader': ['I',
#    'n',
#    's',
#    't',
#    'a',
#    'g',
#    'r',
#    'a',
#    'm',
#    ',',
#    ' ',
#    'F',
#    'a',
#    'c',
#    'e',
#    'b',
#    'o',
#    'o',
#    'k'],
#   'change_profile_pic_actions_screen_upload_cta': ['U',
#    'p',
#    'l',
#    'o',
#    'a',
#    'd',
#    ' ',
#    'P',
#    'h',
#    'o',
#    't',
#    'o'],
#   'change_profile_pic_actions_screen_remove_cta': ['R',
#    'e',
#    'm',
#    'o',
#    'v',
#    'e',
#    ' ',
#    'C',
#    'u',
#    'r',
#    'r',
#    'e',
#    'n',
#    't',
#    ' ',
#    'P',
#    'h',
#    'o',
#    't',
#    'o'],
#   'change_profile_pic_actions_screen_cancel_cta': ['C',
#    'a',
#    'n',
#    'c',
#    'e',
#    'l']},
#  'always_show_message_button_to_pro_account': False}

# %%
k = list(jar.keys())
k
# Out:
# ['seo_category_infos',
#  'logging_page_id',
#  'show_suggested_profiles',
#  'show_follow_dialog',
#  'graphql',
#  'toast_content_on_load',
#  'show_view_shop',
#  'profile_pic_edit_sync_props',
#  'always_show_message_button_to_pro_account']

# %%
gql = jar['graphql']['user']
gql
# Out:
# {'biography': 'Hey Vicks 🍻\n🇮🇳 My Projects are my Imagination to turn into Reality.\n🎊 My Google Chat Bot coded in one night. ❤️\n😜👇',
#  'blocked_by_viewer': False,
#  'restricted_by_viewer': None,
#  'country_block': False,
#  'external_url': 'https://vixtest.herokuapp.com/',
#  'external_url_linkshimmed': 'https://l.instagram.com/?u=https%3A%2F%2Fvixtest.herokuapp.com%2F&e=ATPeDnUd7ARZiNIkZj5DlH6ODl2e_XuFHwCk9mFCzL1Y63YhT7cIFNej0Ua1TxXgmcPnNRJwz7MQImRw&s=1',
#  'edge_followed_by': {'count': 434},
#  'fbid': '17841407073406893',
#  'followed_by_viewer': False,
#  'edge_follow': {'count': 885},
#  'follows_viewer': False,
#  'full_name': 'Vicky Kumar',
#  'has_ar_effects': False,
#  'has_clips': True,
#  'has_guides': False,
#  'has_channel': False,
#  'has_blocked_viewer': False,
#  'highlight_reel_count': 0,
#  'has_requested_viewer': False,
#  'hide_like_and_view_counts': False,
#  'id': '7015147780',
#  'is_business_account': False,
#  'is_professional_account': False,
#  'is_embeds_disabled': False,
#  'is_joined_recently': False,
#  'business_address_json': None,
#  'business_contact_method': 'UNKNOWN',
#  'business_email': None,
#  'business_phone_number': None,
#  'business_category_name': None,
#  'overall_category_name': None,
#  'category_enum': None,
#  'category_name': None,
#  'is_private': True,
#  'is_verified': False,
#  'edge_mutual_followed_by': {'count': 0, 'edges': []},
#  'profile_pic_url': 'https://scontent-del1-2.cdninstagram.com/v/t51.2885-19/s150x150/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=scontent-del1-2.cdninstagram.com&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX-nhihF&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT_P71I-bFzSZ41lM95EfoJEqhDmlDjJSTCWq40Rdqnyng&oe=620926E6&_nc_sid=7bff83',
#  'profile_pic_url_hd': 'https://scontent-del1-2.cdninstagram.com/v/t51.2885-19/s320x320/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=scontent-del1-2.cdninstagram.com&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX-nhihF&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT-NdmT0j6V_Yqgq_KSc_WB10OnfKpWZFcunQ7yfPP5EHg&oe=6208CA9E&_nc_sid=7bff83',
#  'requested_by_viewer': False,
#  'should_show_category': False,
#  'should_show_public_contacts': False,
#  'username': 'imvickykumar999',
#  'connected_fb_page': None,
#  'pronouns': [],
#  'edge_felix_video_timeline': {'count': 4,
#   'page_info': {'has_next_page': False, 'end_cursor': ''},
#   'edges': []},
#  'edge_owner_to_timeline_media': {'count': 28,
#   'page_info': {'has_next_page': False, 'end_cursor': ''},
#   'edges': []},
#  'edge_saved_media': {'count': 0,
#   'page_info': {'has_next_page': False, 'end_cursor': None},
#   'edges': []},
#  'edge_media_collections': {'count': 0,
#   'page_info': {'has_next_page': False, 'end_cursor': None},
#   'edges': []},
#  'edge_related_profiles': {'edges': []}}

# %%
gql.keys()
# Out:
# dict_keys(['biography', 'blocked_by_viewer', 'restricted_by_viewer', 'country_block', 'external_url', 'external_url_linkshimmed', 'edge_followed_by', 'fbid', 'followed_by_viewer', 'edge_follow', 'follows_viewer', 'full_name', 'has_ar_effects', 'has_clips', 'has_guides', 'has_channel', 'has_blocked_viewer', 'highlight_reel_count', 'has_requested_viewer', 'hide_like_and_view_counts', 'id', 'is_business_account', 'is_professional_account', 'is_embeds_disabled', 'is_joined_recently', 'business_address_json', 'business_contact_method', 'business_email', 'business_phone_number', 'business_category_name', 'overall_category_name', 'category_enum', 'category_name', 'is_private', 'is_verified', 'edge_mutual_followed_by', 'profile_pic_url', 'profile_pic_url_hd', 'requested_by_viewer', 'should_show_category', 'should_show_public_contacts', 'username', 'connected_fb_page', 'pronouns', 'edge_felix_video_timeline', 'edge_owner_to_timeline_media', 'edge_saved_media', 'edge_media_collections', 'edge_related_profiles'])

# %%
followers = gql['edge_followed_by']
followers
# Out:
# {'count': 434}

# %%
following = gql['edge_follow']
following
# Out:
# {'count': 885}

# %%
link = gql['profile_pic_url_hd']
link
# Out:
# 'https://scontent-del1-2.cdninstagram.com/v/t51.2885-19/s320x320/269751788_282087027280038_4779994421201724997_n.jpg?_nc_ht=scontent-del1-2.cdninstagram.com&_nc_cat=106&_nc_ohc=j8CZDsYJ_aAAX-nhihF&edm=ABfd0MgBAAAA&ccb=7-4&oh=00_AT-NdmT0j6V_Yqgq_KSc_WB10OnfKpWZFcunQ7yfPP5EHg&oe=6208CA9E&_nc_sid=7bff83'

# %%
# ==========================================================

# %%
url = 'https://www.googleapis.com/youtube/v3/videos?id=mXkbWKr5ovU&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&part=snippet,statistics' 
import requests
import json

resp = requests.get(url=url)
data = resp.json()
data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'HKvv72fLuTE_-owVdYl-zMBqo_w',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'ZVd28k2JZoRn1n18HlLNxW-qguE',
#    'id': 'mXkbWKr5ovU',
#    'snippet': {'publishedAt': '2011-05-22T19:40:14Z',
#     'channelId': 'UCq-Fj5jknLsUf-MWSy4_brA',
#     'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#     'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'T-Series',
#     'tags': ['Main Hoon Na',
#      'Tumse Milke Dilka Jo Haal',
#      'Sonu Nigam',
#      'Altaf Sabri',
#      'Hashim Sabri',
#      'Anu Malik',
#      'Javed Akhtar',
#      'Shahrukh Khan',
#      'Zayed Khan',
#      'yt:crop=16:9',
#      'Main Hoon Na movie songs',
#      'Main Hoon Na shahrukh',
#      'Sonu Nigam songs',
#      'Anu Malik songs',
#      'Javed Akhtar songs',
#      'Shahrukh Khan songs',
#      'Zayed Khan songs',
#      'hindi songs',
#      'bollywood songs',
#      'romantic songs',
#      'love songs',
#      'ghazal songs',
#      'qawali songs',
#      'qawali hindi songs',
#      'hindi',
#      'bollywood',
#      'latest',
#      'hits',
#      'love',
#      'romantic',
#      'qawali',
#      'songs',
#      'tseries songs',
#      'tseries'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#      'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series'},
#     'defaultAudioLanguage': 'hi'},
#    'statistics': {'viewCount': '127863047',
#     'likeCount': '947056',
#     'favoriteCount': '0',
#     'commentCount': '21473'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
data.keys()
# Out:
# dict_keys(['kind', 'etag', 'items', 'pageInfo'])

# %%
item = data['items']
item
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'ZVd28k2JZoRn1n18HlLNxW-qguE',
#   'id': 'mXkbWKr5ovU',
#   'snippet': {'publishedAt': '2011-05-22T19:40:14Z',
#    'channelId': 'UCq-Fj5jknLsUf-MWSy4_brA',
#    'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#    'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/mXkbWKr5ovU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'T-Series',
#    'tags': ['Main Hoon Na',
#     'Tumse Milke Dilka Jo Haal',
#     'Sonu Nigam',
#     'Altaf Sabri',
#     'Hashim Sabri',
#     'Anu Malik',
#     'Javed Akhtar',
#     'Shahrukh Khan',
#     'Zayed Khan',
#     'yt:crop=16:9',
#     'Main Hoon Na movie songs',
#     'Main Hoon Na shahrukh',
#     'Sonu Nigam songs',
#     'Anu Malik songs',
#     'Javed Akhtar songs',
#     'Shahrukh Khan songs',
#     'Zayed Khan songs',
#     'hindi songs',
#     'bollywood songs',
#     'romantic songs',
#     'love songs',
#     'ghazal songs',
#     'qawali songs',
#     'qawali hindi songs',
#     'hindi',
#     'bollywood',
#     'latest',
#     'hits',
#     'love',
#     'romantic',
#     'qawali',
#     'songs',
#     'tseries songs',
#     'tseries'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en',
#    'localized': {'title': 'Tumse Milke Dilka Jo Haal [Full Song] | Main Hoon Na | Shahrukh Khan',
#     'description': 'Subscribe our channel http://www.youtube.com/tseries\nLike us: http://www.facebook.com/tseriesmusic\nFollow us: http://www.twitter.com/_Tseries\n\n\nSong : Tumse Milke Dilka Jo Haal\nAlbum : Main Hoon Na\nStar cast : Shahrukh Khan, Zayed Khan\nSinger : Sonu Nigam, Altaf Sabri, Hashim Sabri \nMusic Director : Anu Malik\nLyricst : Javed Akhtar\nMusic Label : T-Series'},
#    'defaultAudioLanguage': 'hi'},
#   'statistics': {'viewCount': '127863047',
#    'likeCount': '947056',
#    'favoriteCount': '0',
#    'commentCount': '21473'}}]

# %%
type(item)
# Out:
# list

# %%
len(item)
# Out:
# 1

# %%
k = item[0].keys()
k
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet', 'statistics'])

# %%
item[0]['statistics']
# Out:
# {'viewCount': '127863047',
#  'likeCount': '947056',
#  'favoriteCount': '0',
#  'commentCount': '21473'}

# %%
url = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=ATm0cWqowxE&key=AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I&alt=json' 
import requests
import json

resp = requests.get(url=url)
data = resp.json()
data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'yo3wawieZtdKKmJS5nOgUFHfIuo',
#  'nextPageToken': 'QURTSl9pM2RmMi1UU0N3T0k3dUZQd3cxXzRWb1RuOW0wc3R1dlJEeWpKMngzSm1hTTdnWUNUX0gxRmctM2EzQ1dJWk5zSUhpUm1lUnpZdw==',
#  'pageInfo': {'totalResults': 19, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag

#       'authorProfileImageUrl': 'https://yt3.ggpht.com/fgf9G8QNy2S1nrhEIvi6Njrzis6ZPBmun5i6qyZwm3kl1fbvroFaAzO_8ztPc7E0ANf_ZhUvwfI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOtWyVpQ-X0hvz96CePh7Vw',
#       'authorChannelId': {'value': 'UCOtWyVpQ-X0hvz96CePh7Vw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-08T05:09:48Z',
#       'updatedAt': '2022-02-08T05:09:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GXXsETy8ZwyBrEegjKCJfsZb0wQ',
#    'id': 'UgzsFsm0uyFBsiNjXCN4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yE3motSNhEcUYzMA-OEGGja89-M',
#      'id': 'UgzsFsm0uyFBsiNjXCN4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Nice song bro',
#       'textOriginal': 'Nice song bro',
#       'authorDisplayName': 'GJ gaming',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRtX93c0iOPOhZysKYaFMpl99mkcTOdH-AeEw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCo-KNyfewDFbXEnUeKwmnNg',
#       'authorChannelId': {'value': 'UCo-KNyfewDFbXEnUeKwmnNg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-08T04:45:49Z',
#       'updatedAt': '2022-02-08T04:45:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'whdh1-6z_pGGGOHKJvrOdF-pNjc',
#    'id': 'Ugxe6MqIqGZXL24s-SV4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cmR_NwkCf4JePpuaVBQvaHdHuTU',
#      'id': 'Ugxe6MqIqGZXL24s-SV4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'We all r pray save him',
#       'textOriginal': 'We all r pray save him',
#       'authorDisplayName': 'æblue îñd gaming',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/6sfsZIph6y7AlZSVf5fWx2AmkbbPIRhRhkh3uMB1NCWmZTrB7vBi3yaf3_qSrXIMhrWCS5sc5g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5P2SuF-ppA3p-G74Sfr-Vw',
#       'authorChannelId': {'value': 'UC5P2SuF-ppA3p-G74Sfr-Vw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-08T04:05:14Z',
#       'updatedAt': '2022-02-08T04:05:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'v_HvEArvFcQ6ldPM-C6yWVS9vjU',
#    'id': 'UgxSgvf-X2bfcGO7rat4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'D6kK9s7PJRH5I1SjHC8cniiBlZE',
#      'id': 'UgxSgvf-X2bfcGO7rat4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': '😋😋',
#       'textOriginal': '😋😋',
#       'authorDisplayName': 'BIPIN B SINGH',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTSpc5y7L1iNYPsVnSskMFxeRTYbl1kgy7Z4ACCgQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC2jugOPBgExr0gSPEgMHZpA',
#       'authorChannelId': {'value': 'UC2jugOPBgExr0gSPEgMHZpA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T23:06:53Z',
#       'updatedAt': '2022-02-07T23:06:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '8nisZl5kZUou3VfFtG9r3uYH4Ic',
#    'id': 'UgwY4xYEQh5oF9D0gDx4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Dn3UmR-bgVlyMNNjGFlm16SeZt8',
#      'id': 'UgwY4xYEQh5oF9D0gDx4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Get well soon',
#       'textOriginal': 'Get well soon',
#       'authorDisplayName': 'amit kumar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSjK7jQFAl-9s4Vvxqdx-0SBhwkE_gZIU7n6eCo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnjW22eby-Z6oRbLkqmXzsQ',
#       'authorChannelId': {'value': 'UCnjW22eby-Z6oRbLkqmXzsQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T22:46:01Z',
#       'updatedAt': '2022-02-07T22:46:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'B5n-d4G4kyFPr_G2h1ukZO6Q--w',
#    'id': 'Ugx4YK-nngsoIbvJC7l4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9BlG4vQwB2Pd3nT2QHj4p-HJzJY',
#      'id': 'Ugx4YK-nngsoIbvJC7l4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Keep sporting mohsin Ali yt chanal',
#       'textOriginal': 'Keep sporting mohsin Ali yt chanal',
#       'authorDisplayName': 'Neelam Khan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOL

#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS5028_9NIt2-M4NLcCgeVrSx4sTHFk-iR8yfvd=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCANPP42I7Emtzg8turwSuag',
#       'authorChannelId': {'value': 'UCANPP42I7Emtzg8turwSuag'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T18:05:15Z',
#       'updatedAt': '2022-02-07T18:05:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'yepcllYzJZGGECHngS6bdzThnkg',
#    'id': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B2DYZMclWgA6SQ6tYp5taG4neNo',
#      'id': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭',
#       'textOriginal': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭',
#       'authorDisplayName': 'Tanu Choudhary',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTqPEI-QfVVNqN15T_E5wlbFlA8C3kERcEBkqGR2A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzJcLxFWwuYEci7b2sCcESQ',
#       'authorChannelId': {'value': 'UCzJcLxFWwuYEci7b2sCcESQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T17:24:05Z',
#       'updatedAt': '2022-02-07T17:24:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'oWcXLw4O77KMqGoPLKu89m4Yn2c',
#       'id': 'Ugy1KRZKPw16kce4Jq14AaABAg.9Y9Ixbf2kRo9Y9YFyne7Fv',
#       'snippet': {'videoId': 'ATm0cWqowxE',
#        'textDisplay': 'So sad',
#        'textOriginal': 'So sad',
#        'parentId': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#        'authorDisplayName': '3:00 AM FOREVER',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/GpxPM7agAyE40RMAhdrJkN5Jjbqnp1WDCabYoSuwCKxsPzq5hjEvc46-VspLf-O4gm0orsMRKw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/channel/UCf4FUAD5nA89EK9d19mwqyA',
#        'authorChannelId': {'value': 'UCf4FUAD5nA89EK9d19mwqyA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2022-02-07T19:37:47Z',
#        'updatedAt': '2022-02-07T19:37:47Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gek4das4e5DqIiLSbH2Wpy_OkZA',
#    'id': 'Ugzgrzt5aH858ytnZNp4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YR4-NbvpVuGoyfUjx8SyMXXTbv4',
#      'id': 'Ugzgrzt5aH858ytnZNp4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'Excellent mix so keep up the nice and love it',
#       'textOriginal': 'Excellent mix so keep up the nice and love it',
#       'authorDisplayName': 'KAaREhaAN KhAN',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQfsOnqpGQh26Uu0PQzpSZ8yXxkQItygnpWs2Tl=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCp1_IXKipa32i93Zfg6LAGQ',
#       'authorChannelId': {'value': 'UCp1_IXKipa32i93Zfg6LAGQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T16:46:40Z',
#       'updatedAt': '2022-02-07T16:46:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3FJ7GI1KDiYZ5FaaepoDTC_zyaw',
#    'id': 'UgyfINZ61qY10ezqpC14AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'u-lp13YTbxZicEXyoix4yQfxeA8',
#      'id': 'UgyfINZ61qY10ezqpC14AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'English song ka naam kya h jo isme h',
#       'textOriginal': 'English song ka naam kya h jo isme h',
#       'authorDisplayName': 'Shad ji Khan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRnmVgUoP26Fiboq_McwPaJyGWRN6Bc782YbdHsm0aExbdrFH6PnkzsNuiWHCft=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbaNtYF6L2a9SvZZYiDtiog',
#       'authorChannelId': {'value': 'UCbaNtYF6L2a9SvZZYiDtiog'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T14:45:53Z',
#       'updatedAt': '2022-02-07T14:45:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TEDWRzHPTcFbhEuHbrdcTGoy9gg',
#    'id': 'UgyStx_3EGwpm9-BOfd4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ki__Xq3bt_ath9wNe7bnWiRwVIo',
#      'id': 'UgyStx_3EGwpm9-BOfd4AaABAg',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'This type of songs always force me to do love with my self and my dreams... 😂',
#       'textOriginal': 'This type of songs always force me to do love with my self and my dreams... 😂',
#       'authorDisplayName': 'Sachin Yadav00',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRWrYG1hLVagq_q68tm0hlM5uShwUj-8XT3D3YI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCno3foYEZK8vyYP7IMdbMHg',
#       'authorChannelId': {'value': 'UCno3foYEZK8vyYP7IMdbMHg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-07T14:31:51Z',
#       'updatedAt': '2022-02-07T14:31:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
data.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
item = data['items']
item
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'Zr0sZBop7DLj8-RUxm4HCGFiBnk',
#   'id': 'UgyZWvyDU3nHkHUK9s94AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'g_Kgz2_DvsrnqJ8aYpYlN7FN_Kw',
#     'id': 'UgyZWvyDU3nHkHUK9s94AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'May the good God bless u and your family ❣️',
#      'textOriginal': 'May the good God bless u and your family ❣️',
#      'authorDisplayName': 'Toxic CDR',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS2YSd-8jZqTPPFYIr3BM3vvEEpuBEnA4ZnT-PlG6U=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCZxO9BsTGaV-M8EP6Ktl-Zw',
#      'authorChannelId': {'value': 'UCZxO9BsTGaV-M8EP6Ktl-Zw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T07:19:03Z',
#      'updatedAt': '2022-02-08T07:19:03Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'LqgtMxf8zDRe0RXvUnS9ogLlT7w',
#   'id': 'UgxP0wDorsf4q0BjUNl4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'YZ50klYW99xlQ30bOJ54f0ZvW_s',
#     'id': 'UgxP0wDorsf4q0BjUNl4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'nice song 💓💓💓💓💓💓',
#      'textOriginal': 'nice song 💓💓💓💓💓💓',
#      'authorDisplayName': 'Vishal. Kumar Panchal',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQKveQaTx2U73NRMoMW6Ar3CJ4JalaMs7WBAw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCos56UwcIWlSm8NdTgTnotA',
#      'authorChannelId': {'value': 'UCos56UwcIWlSm8NdTgTnotA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T07:03:05Z',
#      'updatedAt': '2022-02-08T07:03:05Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'AI9O4zzJhVHBWdVFhNHFCQAdzqo',
#   'id': 'UgzwqmV3bIgBZkiHw-F4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'xMt42Aiu-VkDHTJHDNIomGPMRDE',
#     'id': 'UgzwqmV3bIgBZkiHw-F4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'U75O;L;',
#      'textOriginal': 'U75O;L;',
#      'authorDisplayName': 'shehroz asad',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQOdUKfoW6UFWuqAsj8MOXrTthI4y_OUi63thHFMOpNKkQaxlnVomH8SVJaSQcy=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCm8rpR4dFvAH0h3uWmL9RSA',
#      'authorChannelId': {'value': 'UCm8rpR4dFvAH0h3uWmL9RSA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T07:00:02Z',
#      'updatedAt': '2022-02-08T07:00:02Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'paH5eJwSDvRMuekxflsVsJ1WG9k',
#   'id': 'UgxNEisA-D5vrZQ0SgV4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'zPgZm8FP6CTTtkUtvlRLu4jmopA',
#     'id': 'UgxNEisA-D5vrZQ0SgV4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Heart touching song❤❤❤❤',
#      'textOriginal': 'Heart touching song❤❤❤❤',
#      'authorDisplayName': 'अयोध्या वाले🙏',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/UTw4sIUOHTPORJmSuRn3vreF4NF2P1nKetqt5yNnz2EXvY9OmTiOzJIltIy3YL6djm1BeA1D=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC4H5MT-qpaCLJttNXS78BRQ',
#      'authorChannelId': {'value': 'UC4H5MT-qpaCLJttNXS78BRQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T05:22:46Z',
#      'updatedAt': '2022-02-08T05:22:46Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'wnFqnasUkmTPgRTk9fmVjEsxB4k',
#   'id': 'Ugy0gBJoOyIXh9DF1cF4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'nfSCajYawUd7Wsdi3a8KaAzuPRA',
#     'id': 'Ugy0gBJoOyIXh9DF1cF4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'vfbfjbf',
#      'textOriginal': 'vfbfjbf',
#      'authorDisplayName': 'Hitesh Raj',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/fgf9G8QNy2S1nrhEIvi6Njrzis6ZPBmun5i6qyZwm3kl1fbvroFaAzO_8ztPc7E0ANf_ZhUvwfI=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCOtWyVpQ-X0hvz96CePh7Vw',
#      'authorChannelId': {'value': 'UCOtWyVpQ-X0hvz96CePh7Vw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-08T05:09:48Z',
#      'updatedAt': '2022-02-08T05:09:48Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'GXXsETy8ZwyBrEegjKCJfsZb0wQ',
#   'id': 'UgzsFsm0uyFBsiNjXCN4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'yE3motSNhEcUYzMA-OEGGja89-M',
#     'id': 'UgzsFsm0uyFBsiNjXCN4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Nice song bro',
#      'textOriginal': 'Nice song bro',
#      'authorDisplayName': 'GJ gaming',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRtX93c0iOPOhZysKYaFMpl99mkcTOdH-AeEw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCo-KNyfewDFbXEnUeKwmnNg',
#      'authorChannelId': {'value': 'UCo-KNyfewDFbXEnUeKwmnNg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T04:45:49Z',
#      'updatedAt': '2022-02-08T04:45:49Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'whdh1-6z_pGGGOHKJvrOdF-pNjc',
#   'id': 'Ugxe6MqIqGZXL24s-SV4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'cmR_NwkCf4JePpuaVBQvaHdHuTU',
#     'id': 'Ugxe6MqIqGZXL24s-SV4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'We all r pray save him',
#      'textOriginal': 'We all r pray save him',
#      'authorDisplayName': 'æblue îñd gaming',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/6sfsZIph6y7AlZSVf5fWx2AmkbbPIRhRhkh3uMB1NCWmZTrB7vBi3yaf3_qSrXIMhrWCS5sc5g=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC5P2SuF-ppA3p-G74Sfr-Vw',
#      'authorChannelId': {'value': 'UC5P2SuF-ppA3p-G74Sfr-Vw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-08T04:05:14Z',
#      'updatedAt': '2022-02-08T04:05:14Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'v_HvEArvFcQ6ldPM-C6yWVS9vjU',
#   'id': 'UgxSgvf-X2bfcGO7rat4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'D6kK9s7PJRH5I1SjHC8cniiBlZE',
#     'id': 'UgxSgvf-X2bfcGO7rat4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': '😋😋',
#      'textOriginal': '😋😋',
#      'authorDisplayName': 'BIPIN B SINGH',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTSpc5y7L1iNYPsVnSskMFxeRTYbl1kgy7Z4ACCgQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC2jugOPBgExr0gSPEgMHZpA',
#      'authorChannelId': {'value': 'UC2jugOPBgExr0gSPEgMHZpA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T23:06:53Z',
#      'updatedAt': '2022-02-07T23:06:53Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '8nisZl5kZUou3VfFtG9r3uYH4Ic',
#   'id': 'UgwY4xYEQh5oF9D0gDx4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Dn3UmR-bgVlyMNNjGFlm16SeZt8',
#     'id': 'UgwY4xYEQh5oF9D0gDx4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Get well soon',
#      'textOriginal': 'Get well soon',
#      'authorDisplayName': 'amit kumar',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSjK7jQFAl-9s4Vvxqdx-0SBhwkE_gZIU7n6eCo=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCnjW22eby-Z6oRbLkqmXzsQ',
#      'authorChannelId': {'value': 'UCnjW22eby-Z6oRbLkqmXzsQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T22:46:01Z',
#      'updatedAt': '2022-02-07T22:46:01Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'B5n-d4G4kyFPr_G2h1ukZO6Q--w',
#   'id': 'Ugx4YK-nngsoIbvJC7l4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '9BlG4vQwB2Pd3nT2QHj4p-HJzJY',
#     'id': 'Ugx4YK-nngsoIbvJC7l4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Keep sporting mohsin Ali yt chanal',
#      'textOriginal': 'Keep sporting mohsin Ali yt chanal',
#      'authorDisplayName': 'Neelam Khan',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRj1MrUKHIzRM6or8FDd8_BjRZZhL2ldkz6fgGl5KFafGZSR3oZqUSRrgDMSrHM=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCabRyp8yQkoW-FAQbrKbLLA',
#      'authorChannelId': {'value': 'UCabRyp8yQkoW-FAQbrKbLLA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T22:22:18Z',
#      'updatedAt': '2022-02-07T22:22:18Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'kOevkRE_S4NaFOQsZL4eiI1eJzA',
#   'id': 'UgwtqsZp8LbzXFiZEeh4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '7fGmSrbkXJw37kLKMC36Rq-TcNk',
#     'id': 'UgwtqsZp8LbzXFiZEeh4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'last wala song just master pice❤️❤️ plz kisika patah heto sirf last wala song ka name mention kariye..😊',
#      'textOriginal': 'last wala song just master pice❤️❤️ plz kisika patah heto sirf last wala song ka name mention kariye..😊',
#      'authorDisplayName': 'Ahmed fahim',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRDyDGq_goujbyC7NZOWhIBqJ4ydqa-smWZVQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC1nr3314LFPUJmHidX80naQ',
#      'authorChannelId': {'value': 'UC1nr3314LFPUJmHidX80naQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T21:21:19Z',
#      'updatedAt': '2022-02-08T04:39:23Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'UTfXymHsMqHpIrffpa5px4fJG78',
#   'id': 'Ugy5b09tY3FhvRXntzt4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Z8r1ST1HZBlR6AOk9TA1CQwQ4Qg',
#     'id': 'Ugy5b09tY3FhvRXntzt4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Nice Collection Bro 🤗',
#      'textOriginal': 'Nice Collection Bro 🤗',
#      'authorDisplayName': 'K Chauhan',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRoY71gfgXcpHxgwaWZNbsbOiWoreiNHFOtSYOohw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCkeMkzhDUbJKKzLKP7iUQaQ',
#      'authorChannelId': {'value': 'UCkeMkzhDUbJKKzLKP7iUQaQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T20:19:57Z',
#      'updatedAt': '2022-02-07T20:19:57Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'NI5HiqEqyIcDSdztlw7kU2N8onw',
#   'id': 'UgwIIFtce239XUz6Q9V4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'fjUosIUjtYieRPDmV_Vq91vNs4A',
#     'id': 'UgwIIFtce239XUz6Q9V4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Get well soon',
#      'textOriginal': 'Get well soon',
#      'authorDisplayName': 'Prashant Chauhan',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSZQoo_IIW0vFyGys8iSh3D5GOqW4h2vk3pRA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCadaW618I4MwF9nR082GI_w',
#      'authorChannelId': {'value': 'UCadaW618I4MwF9nR082GI_w'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T20:17:37Z',
#      'updatedAt': '2022-02-07T20:17:37Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '3t2GscnjUCDJlm7GLsFIcXJ1I90',
#   'id': 'Ugx4IDlnVW0BEM7sX6R4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Vlb4RqkOi5Gq9UiAbW0dk2l-4zg',
#     'id': 'Ugx4IDlnVW0BEM7sX6R4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Awesome yr 🔥💔👌',
#      'textOriginal': 'Awesome yr 🔥💔👌',
#      'authorDisplayName': 'sabir ali',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/OTxxAqAoDaM4eQFTjj9BEsGy00yt0_ssROtTB_X2kjV5O408S6XEe7mHDDWCT10O4fdOnR1s=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCIZ7ztgGKlKo0N5uw3lm9Kg',
#      'authorChannelId': {'value': 'UCIZ7ztgGKlKo0N5uw3lm9Kg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T18:41:00Z',
#      'updatedAt': '2022-02-07T18:41:00Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'vQc3T-4IQFijN3N0ZNrfsw4BKJ4',
#   'id': 'Ugx4Nm16bHPH-CMT-jF4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'yqBzF76ZeYH2zoD0KxZS5J8Bm9w',
#     'id': 'Ugx4Nm16bHPH-CMT-jF4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Pari arjun ❤️👍',
#      'textOriginal': 'Pari arjun ❤️👍',
#      'authorDisplayName': 'Arjun Arjun',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS5028_9NIt2-M4NLcCgeVrSx4sTHFk-iR8yfvd=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCANPP42I7Emtzg8turwSuag',
#      'authorChannelId': {'value': 'UCANPP42I7Emtzg8turwSuag'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T18:05:15Z',
#      'updatedAt': '2022-02-07T18:05:15Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'yepcllYzJZGGECHngS6bdzThnkg',
#   'id': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'B2DYZMclWgA6SQ6tYp5taG4neNo',
#     'id': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭',
#      'textOriginal': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭',
#      'authorDisplayName': 'Tanu Choudhary',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTqPEI-QfVVNqN15T_E5wlbFlA8C3kERcEBkqGR2A=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCzJcLxFWwuYEci7b2sCcESQ',
#      'authorChannelId': {'value': 'UCzJcLxFWwuYEci7b2sCcESQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T17:24:05Z',
#      'updatedAt': '2022-02-07T17:24:05Z'}},
#    'canReply': True,
#    'totalReplyCount': 1,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'oWcXLw4O77KMqGoPLKu89m4Yn2c',
#      'id': 'Ugy1KRZKPw16kce4Jq14AaABAg.9Y9Ixbf2kRo9Y9YFyne7Fv',
#      'snippet': {'videoId': 'ATm0cWqowxE',
#       'textDisplay': 'So sad',
#       'textOriginal': 'So sad',
#       'parentId': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#       'authorDisplayName': '3:00 AM FOREVER',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/GpxPM7agAyE40RMAhdrJkN5Jjbqnp1WDCabYoSuwCKxsPzq5hjEvc46-VspLf-O4gm0orsMRKw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCf4FUAD5nA89EK9d19mwqyA',
#       'authorChannelId': {'value': 'UCf4FUAD5nA89EK9d19mwqyA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-07T19:37:47Z',
#       'updatedAt': '2022-02-07T19:37:47Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'gek4das4e5DqIiLSbH2Wpy_OkZA',
#   'id': 'Ugzgrzt5aH858ytnZNp4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'YR4-NbvpVuGoyfUjx8SyMXXTbv4',
#     'id': 'Ugzgrzt5aH858ytnZNp4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'Excellent mix so keep up the nice and love it',
#      'textOriginal': 'Excellent mix so keep up the nice and love it',
#      'authorDisplayName': 'KAaREhaAN KhAN',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQfsOnqpGQh26Uu0PQzpSZ8yXxkQItygnpWs2Tl=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCp1_IXKipa32i93Zfg6LAGQ',
#      'authorChannelId': {'value': 'UCp1_IXKipa32i93Zfg6LAGQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T16:46:40Z',
#      'updatedAt': '2022-02-07T16:46:40Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '3FJ7GI1KDiYZ5FaaepoDTC_zyaw',
#   'id': 'UgyfINZ61qY10ezqpC14AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'u-lp13YTbxZicEXyoix4yQfxeA8',
#     'id': 'UgyfINZ61qY10ezqpC14AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'English song ka naam kya h jo isme h',
#      'textOriginal': 'English song ka naam kya h jo isme h',
#      'authorDisplayName': 'Shad ji Khan',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRnmVgUoP26Fiboq_McwPaJyGWRN6Bc782YbdHsm0aExbdrFH6PnkzsNuiWHCft=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCbaNtYF6L2a9SvZZYiDtiog',
#      'authorChannelId': {'value': 'UCbaNtYF6L2a9SvZZYiDtiog'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-07T14:45:53Z',
#      'updatedAt': '2022-02-07T14:45:53Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'TEDWRzHPTcFbhEuHbrdcTGoy9gg',
#   'id': 'UgyStx_3EGwpm9-BOfd4AaABAg',
#   'snippet': {'videoId': 'ATm0cWqowxE',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Ki__Xq3bt_ath9wNe7bnWiRwVIo',
#     'id': 'UgyStx_3EGwpm9-BOfd4AaABAg',
#     'snippet': {'videoId': 'ATm0cWqowxE',
#      'textDisplay': 'This type of songs always force me to do love with my self and my dreams... 😂',
#      'textOriginal': 'This type of songs always force me to do love with my self and my dreams... 😂',
#      'authorDisplayName': 'Sachin Yadav00',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRWrYG1hLVagq_q68tm0hlM5uShwUj-8XT3D3YI=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCno3foYEZK8vyYP7IMdbMHg',
#      'authorChannelId': {'value': 'UCno3foYEZK8vyYP7IMdbMHg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-07T14:31:51Z',
#      'updatedAt': '2022-02-07T14:31:51Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}}]

# %%
len(item)
# Out:
# 19

# %%
item[1]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'LqgtMxf8zDRe0RXvUnS9ogLlT7w',
#  'id': 'UgxP0wDorsf4q0BjUNl4AaABAg',
#  'snippet': {'videoId': 'ATm0cWqowxE',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'YZ50klYW99xlQ30bOJ54f0ZvW_s',
#    'id': 'UgxP0wDorsf4q0BjUNl4AaABAg',
#    'snippet': {'videoId': 'ATm0cWqowxE',
#     'textDisplay': 'nice song 💓💓💓💓💓💓',
#     'textOriginal': 'nice song 💓💓💓💓💓💓',
#     'authorDisplayName': 'Vishal. Kumar Panchal',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQKveQaTx2U73NRMoMW6Ar3CJ4JalaMs7WBAw=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/channel/UCos56UwcIWlSm8NdTgTnotA',
#     'authorChannelId': {'value': 'UCos56UwcIWlSm8NdTgTnotA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2022-02-08T07:03:05Z',
#     'updatedAt': '2022-02-08T07:03:05Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
com = item[1]['snippet']['topLevelComment']['snippet']['textOriginal']
com
# Out:
# 'nice song 💓💓💓💓💓💓'

# %%
for i in item:
    print(i['snippet']['topLevelComment']['snippet']['textOriginal'])
# Out:
# May the good God bless u and your family ❣️
# nice song 💓💓💓💓💓💓
# U75O;L;
# Heart touching song❤❤❤❤
# vfbfjbf
# Nice song bro
# We all r pray save him
# 😋😋
# Get well soon
# Keep sporting mohsin Ali yt chanal
# last wala song just master pice❤️❤️ plz kisika patah heto sirf last wala song ka name mention kariye..😊
# Nice Collection Bro 🤗
# Get well soon
# Awesome yr 🔥💔👌
# Pari arjun ❤️👍
# Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭
# Excellent mix so keep up the nice and love it
# English song ka naam kya h jo isme h
# This type of songs always force me to do love with my self and my dreams... 😂

# %%
print(url)
# Out:
# https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%
 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS5028_9NIt2-M4NLcCgeVrSx4sTHFk-iR8yfvd=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCANPP42I7Emtzg8turwSuag', 'authorChannelId': {'value': 'UCANPP42I7Emtzg8turwSuag'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-07T18:05:15Z', 'updatedAt': '2022-02-07T18:05:15Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
#
# {'kind': 'youtube#commentThread', 'etag': 'yepcllYzJZGGECHngS6bdzThnkg', 'id': 'Ugy1KRZKPw16kce4Jq14AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'B2DYZMclWgA6SQ6tYp5taG4neNo', 'id': 'Ugy1KRZKPw16kce4Jq14AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭', 'textOriginal': 'Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭', 'authorDisplayName': 'Tanu Choudhary', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTqPEI-QfVVNqN15T_E5wlbFlA8C3kERcEBkqGR2A=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCzJcLxFWwuYEci7b2sCcESQ', 'authorChannelId': {'value': 'UCzJcLxFWwuYEci7b2sCcESQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-07T17:24:05Z', 'updatedAt': '2022-02-07T17:24:05Z'}}, 'canReply': True, 'totalReplyCount': 1, 'isPublic': True}, 'replies': {'comments': [{'kind': 'youtube#comment', 'etag': 'oWcXLw4O77KMqGoPLKu89m4Yn2c', 'id': 'Ugy1KRZKPw16kce4Jq14AaABAg.9Y9Ixbf2kRo9Y9YFyne7Fv', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'So sad', 'textOriginal': 'So sad', 'parentId': 'Ugy1KRZKPw16kce4Jq14AaABAg', 'authorDisplayName': '3:00 AM FOREVER', 'authorProfileImageUrl': 'https://yt3.ggpht.com/GpxPM7agAyE40RMAhdrJkN5Jjbqnp1WDCabYoSuwCKxsPzq5hjEvc46-VspLf-O4gm0orsMRKw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCf4FUAD5nA89EK9d19mwqyA', 'authorChannelId': {'value': 'UCf4FUAD5nA89EK9d19mwqyA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-07T19:37:47Z', 'updatedAt': '2022-02-07T19:37:47Z'}}]}}
#
# {'kind': 'youtube#commentThread', 'etag': 'gek4das4e5DqIiLSbH2Wpy_OkZA', 'id': 'Ugzgrzt5aH858ytnZNp4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'YR4-NbvpVuGoyfUjx8SyMXXTbv4', 'id': 'Ugzgrzt5aH858ytnZNp4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'Excellent mix so keep up the nice and love it', 'textOriginal': 'Excellent mix so keep up the nice and love it', 'authorDisplayName': 'KAaREhaAN KhAN', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQfsOnqpGQh26Uu0PQzpSZ8yXxkQItygnpWs2Tl=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCp1_IXKipa32i93Zfg6LAGQ', 'authorChannelId': {'value': 'UCp1_IXKipa32i93Zfg6LAGQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-07T16:46:40Z', 'updatedAt': '2022-02-07T16:46:40Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
#
# {'kind': 'youtube#commentThread', 'etag': '3FJ7GI1KDiYZ5FaaepoDTC_zyaw', 'id': 'UgyfINZ61qY10ezqpC14AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'u-lp13YTbxZicEXyoix4yQfxeA8', 'id': 'UgyfINZ61qY10ezqpC14AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'English song ka naam kya h jo isme h', 'textOriginal': 'English song ka naam kya h jo isme h', 'authorDisplayName': 'Shad ji Khan', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRnmVgUoP26Fiboq_McwPaJyGWRN6Bc782YbdHsm0aExbdrFH6PnkzsNuiWHCft=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCbaNtYF6L2a9SvZZYiDtiog', 'authorChannelId': {'value': 'UCbaNtYF6L2a9SvZZYiDtiog'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-02-07T14:45:53Z', 'updatedAt': '2022-02-07T14:45:53Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}
#
# {'kind': 'youtube#commentThread', 'etag': 'TEDWRzHPTcFbhEuHbrdcTGoy9gg', 'id': 'UgyStx_3EGwpm9-BOfd4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'Ki__Xq3bt_ath9wNe7bnWiRwVIo', 'id': 'UgyStx_3EGwpm9-BOfd4AaABAg', 'snippet': {'videoId': 'ATm0cWqowxE', 'textDisplay': 'This type of songs always force me to do love with my self and my dreams... 😂', 'textOriginal': 'This type of songs always force me to do love with my self and my dreams... 😂', 'authorDisplayName': 'Sachin Yadav00', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRWrYG1hLVagq_q68tm0hlM5uShwUj-8XT3D3YI=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCno3foYEZK8vyYP7IMdbMHg', 'authorChannelId': {'value': 'UCno3foYEZK8vyYP7IMdbMHg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2022-02-07T14:31:51Z', 'updatedAt': '2022-02-07T14:31:51Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}

# %%
item[15].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet', 'replies'])

# %%
rep = item[15]['replies']['comments'][0]
rep
# Out:
# {'kind': 'youtube#comment',
#  'etag': 'oWcXLw4O77KMqGoPLKu89m4Yn2c',
#  'id': 'Ugy1KRZKPw16kce4Jq14AaABAg.9Y9Ixbf2kRo9Y9YFyne7Fv',
#  'snippet': {'videoId': 'ATm0cWqowxE',
#   'textDisplay': 'So sad',
#   'textOriginal': 'So sad',
#   'parentId': 'Ugy1KRZKPw16kce4Jq14AaABAg',
#   'authorDisplayName': '3:00 AM FOREVER',
#   'authorProfileImageUrl': 'https://yt3.ggpht.com/GpxPM7agAyE40RMAhdrJkN5Jjbqnp1WDCabYoSuwCKxsPzq5hjEvc46-VspLf-O4gm0orsMRKw=s48-c-k-c0x00ffffff-no-rj',
#   'authorChannelUrl': 'http://www.youtube.com/channel/UCf4FUAD5nA89EK9d19mwqyA',
#   'authorChannelId': {'value': 'UCf4FUAD5nA89EK9d19mwqyA'},
#   'canRate': True,
#   'viewerRating': 'none',
#   'likeCount': 0,
#   'publishedAt': '2022-02-07T19:37:47Z',
#   'updatedAt': '2022-02-07T19:37:47Z'}}

# %%
rep.keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
rep['snippet']['textOriginal']
# Out:
# 'So sad'

# %%
for i in item:
    print(i['snippet']['topLevelComment']['snippet']['textOriginal'])
    if i['snippet']['totalReplyCount']:
        print('\t----> ', i['replies']['comments'][0]['snippet']['textOriginal'])
    print()
# Out:
# May the good God bless u and your family ❣️
#
# nice song 💓💓💓💓💓💓
#
# U75O;L;
#
# Heart touching song❤❤❤❤
#
# vfbfjbf
#
# Nice song bro
#
# We all r pray save him
#
# 😋😋
#
# Get well soon
#
# Keep sporting mohsin Ali yt chanal
#
# last wala song just master pice❤️❤️ plz kisika patah heto sirf last wala song ka name mention kariye..😊
#
# Nice Collection Bro 🤗
#
# Get well soon
#
# Awesome yr 🔥💔👌
#
# Pari arjun ❤️👍
#
# Tanudit ❤️💔isme mera or mere bf ka nam h vo muje chor k chlagya.... And i m waiting 3saal se lekin vo kisior k liye chlagya na mujse kiya kbhi na ussy kiya kbhi but m sb jaante hue aaj b bht pyar krti hu ussy bht zda 😭😭😭
# 	---->  So sad
#
# Excellent mix so keep up the nice and love it
#
# English song ka naam kya h jo isme h
#
# This type of songs always force me to do love with my self and my dreams... 😂
