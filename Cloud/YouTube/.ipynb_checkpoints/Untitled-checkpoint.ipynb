# %%
# !pip install --upgrade google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.37.0-py2.py3-none-any.whl (8.1 MB)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.15.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-python-client) (0.18.1)
# Requirement already satisfied, skipping upgrade: google-auth<3.0.0dev,>=1.16.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-python-client) (2.5.0)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.1.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied, skipping upgrade: google-api-core<3.0.0dev,>=1.21.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-python-client) (1.23.0)
# Requirement already satisfied, skipping upgrade: uritemplate<5,>=3.0.1 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\vicky\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.6)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\vicky\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<6.0,>=2.0.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.2.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.13.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (49.2.0.post20200714)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\vicky\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2020.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.27.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\vicky\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.52.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in c:\users\vicky\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in c:\users\vicky\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\vicky\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2020.6.20)
# Requirement already satisfied, skipping upgrade: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\vicky\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.0.9)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\vicky\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.26.7)
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.36.0
#     Uninstalling google-api-python-client-2.36.0:
#       Successfully uninstalled google-api-python-client-2.36.0
# Successfully installed google-api-python-client-2.37.0

# %%
API_key = 'AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I'
API_key
# Out:
# 'AIzaSyC3EsHgVkGg11WfvEgVYuamubsGsjq1n-I'

# %%
# API client library
import googleapiclient.discovery

# API information
api_service_name = "youtube"
api_version = "v3"

# API key
DEVELOPER_KEY = API_key

# API client
youtube_object = googleapiclient.discovery.build(
        api_service_name, 
        api_version, 
        developerKey = DEVELOPER_KEY
)

# %%
maxResults = 10
search_keyword = youtube_object.search().list(
                q = 'doremon', 
                part = "id, snippet",
                maxResults = maxResults
                ).execute()

search_keyword
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'UCKqY_cOwWJcLlblhXvV8d0FXaU',
#  'nextPageToken': 'CAoQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 10},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'jEotIuyar2WlNCW_BR-9wInqqS8',
#    'id': {'kind': 'youtube#video', 'videoId': '-SUkwdhsJzg'},
#    'snippet': {'publishedAt': '2022-02-10T02:00:11Z',
#     'channelId': 'UCwn8uz7_DejtC9fRFdX5zWw',
#     'title': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2021',
#     'description': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2020 Latest Doraemon New Full Episode in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-SUkwdhsJzg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-SUkwdhsJzg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-SUkwdhsJzg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mustidoc',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-10T02:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QeUP9YD2wAYWW7EiaTEjf48FLCM',
#    'id': {'kind': 'youtube#video', 'videoId': 'mX_gNmq0OKI'},
#    'snippet': {'publishedAt': '2022-02-10T03:00:12Z',
#     'channelId': 'UCwn8uz7_DejtC9fRFdX5zWw',
#     'title': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2021',
#     'description': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2020 Latest Doraemon New Full Episode in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mX_gNmq0OKI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mX_gNmq0OKI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mX_gNmq0OKI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mustidoc',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-10T03:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'St-whmV4-EzukHRKlN7tb15G-hI',
#    'id': {'kind': 'youtube#video', 'videoId': 'pO33IqjpRsM'},
#    'snippet': {'publishedAt': '2021-04-25T20:08:58Z',
#     'channelId': 'UC89QAOnAQ9Xs5KS-22mgJpw',
#     'title': 'Doraemon New Episode In Hindi 2021 // Doraemon Cartoon In Hindi // #doraemoninhindi HD #44',
#     'description': 'Doraemon Latest Episode in Hindi | Doremon cartoon in Hindi | Doraemon in Hindi Doraemon in Hindi Full Episode of Doremon ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pO33IqjpRsM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pO33IqjpRsM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pO33IqjpRsM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Debuu UT',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-25T20:08:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '60tRO0VTmDC1VKQSU50D4AY5R6M',
#    'id': {'kind': 'youtube#video', 'videoId': 'RIzkrWx7mBw'},
#    'snippet': {'publishedAt': '2022-02-07T05:34:31Z',
#     'channelId': 'UChoIbWuJpbOp3klVLa7e1dA',
#     'title': 'Doraemon New Episode in Hindi | Doraemon Cartoon | Doraemon latest episode',
#     'description': 'Doraemon New Episode in Hindi | Doraemon Cartoon | Doraemon latest episode doraemon wale cartoon doraemon cartoon in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RIzkrWx7mBw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RIzkrWx7mBw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RIzkrWx7mBw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ahtisham YT Gaming',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-07T05:34:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WaNwdgRCZ49KGt-xTvKleDPIF6Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'UwTJ4tyLUPo'},
#    'snippet': {'publishedAt': '2021-12-29T08:40:53Z',
#     'channelId': 'UC3oT93oqp87BV6ANkOTQw7A',
#     'title': 'Doraemon new episode in Hindi || doraemon horror episode in hindi || doraemon cartoon in hindi 2021',
#     'description': 'my new vlog link      https://youtu.be/8oigWQ2-Rss ignore tags     doraemon cartoon, doraemon movie, doraemon in hindi, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UwTJ4tyLUPo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UwTJ4tyLUPo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UwTJ4tyLUPo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Gautam Sharma vlogs',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-29T08:40:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8v7S0QL5H40JQF-45oHRh6CxSu4',
#    'id': {'kind': 'youtube#video', 'videoId': 'xhCsgT1rLGQ'},
#    'snippet': {'publishedAt': '2022-02-10T04:00:11Z',
#     'channelId': 'UCwn8uz7_DejtC9fRFdX5zWw',
#     'title': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2021',
#     'description': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2020 Latest Doraemon New Full Episode in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xhCsgT1rLGQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xhCsgT1rLGQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xhCsgT1rLGQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mustidoc',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-10T04:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eJwWzcRdkYBCVb5nTkZE3oFl1sg',
#    'id': {'kind': 'youtube#video', 'videoId': 'nEBkygxdG9o'},
#    'snippet': {'publishedAt': '2022-02-10T05:00:12Z',
#     'channelId': 'UCwn8uz7_DejtC9fRFdX5zWw',
#     'title': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2021',
#     'description': 'Doraemon New Episodes in Hindi | Doraemon Cartoon in Hindi | Doraemon in Hindi 2020 Latest Doraemon New Full Episode in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nEBkygxdG9o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nEBkygxdG9o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nEBkygxdG9o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mustidoc',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-10T05:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kXtyWC--Umylnh7-rN_mUwAvhVQ',
#    'id': {'kind': 'youtube#video', 'videoId': '-AyuAcZRr6g'},
#    'snippet': {'publishedAt': '2021-11-01T02:39:43Z',
#     'channelId': 'UCf_D8vVQ5oFARnJCaAnk6bw',
#     'title': 'Doraemon New Episodes In Hindi | doremon cartoon in hindi | doraemon cartoon in 2021| #Doraemon',
#     'description': 'SUBSCRIBE OR I TAKE YOUR DOG ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-AyuAcZRr6g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-AyuAcZRr6g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-AyuAcZRr6g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Illuminati 1k · 18.7K views · 7 minutes ago',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-01T02:39:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kQTgZlR-p6ZC7Y99JZZVAOuuGRc',
#    'id': {'kind': 'youtube#video', 'videoId': 'hNMX73NaYtk'},
#    'snippet': {'publishedAt': '2021-08-03T13:43:49Z',
#     'channelId': 'UC1kl76viHcUDscTyT4mDwvw',
#     'title': 'DOREMON FULL NEW EPISODE || WITHOUT ZOOM EFFECT',
#     'description': 'doraemon movie #doremonnewepinhindi #doraemoninhindi doremon new ep in hindi movie #doraemondoraemon doremon ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hNMX73NaYtk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hNMX73NaYtk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hNMX73NaYtk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Doraemon-Hindi',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-03T13:43:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Vp0xI_ee61uOg0QmVi-e02Te3tQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'q_p2wFFRkMY'},
#    'snippet': {'publishedAt': '2020-02-01T18:56:43Z',
#     'channelId': 'UCQmjQYbD-ZYCf0NgjzzA9DQ',
#     'title': 'Doremon carton new episod 2020',
#     'description': 'Doremon new episod 2020.editted video.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q_p2wFFRkMY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/q_p2wFFRkMY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/q_p2wFFRkMY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Intertainment Plans',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-02-01T18:56:43Z'}}]}

# %%
for i in range(maxResults):
    vid = search_keyword['items'][i]['id']['videoId']
    print('https://www.youtube.com/watch?v=' + vid)
# Out:
# https://www.youtube.com/watch?v=-SUkwdhsJzg
# https://www.youtube.com/watch?v=mX_gNmq0OKI
# https://www.youtube.com/watch?v=pO33IqjpRsM
# https://www.youtube.com/watch?v=RIzkrWx7mBw
# https://www.youtube.com/watch?v=UwTJ4tyLUPo
# https://www.youtube.com/watch?v=xhCsgT1rLGQ
# https://www.youtube.com/watch?v=nEBkygxdG9o
# https://www.youtube.com/watch?v=-AyuAcZRr6g
# https://www.youtube.com/watch?v=hNMX73NaYtk
# https://www.youtube.com/watch?v=q_p2wFFRkMY
