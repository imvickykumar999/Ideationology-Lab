# %%
# importing PIL Module
from PIL import Image

# open the original image
original_img = Image.open("college id.jpg")

flipped_img = original_img.transpose(method=Image.FLIP_LEFT_RIGHT)
# flipped_img = original_img.transpose(method=Image.FLIP_TOP_BOTTOM)

# flipped_img.save("flipped_img.png")

# close all our files object
# original_img.close()
# flipped_img.close()

# %%
original_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1003x683 at 0x25E5530BE20>

# %%
flipped_img
# Out:
# <PIL.Image.Image image mode=RGB size=1003x683 at 0x25E5530BF70>
